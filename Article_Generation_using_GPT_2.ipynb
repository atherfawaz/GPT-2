# %% [markdown]
# <a href="https://colab.research.google.com/github/atherfawaz/GPT-2/blob/master/Article_Generation_using_GPT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 4 - Finetune GPT-2
# This colab demonstrates how to fine-tune GPT-2 on a dataset of presidential speeches. We use the [Hugging Face Transformer](https://github.com/huggingface/transformers) library in order to do this.
#
# **IMPORTANT: Make sure that you have GPU set as your Hardware Accelerator in `Runtime > Change runtime type` before running this Colab.**

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Install HuggingFace Transfomers library.

# %%
# !git clone https://github.com/huggingface/transformers

import os
os.chdir('/content/transformers')

# !pip3 install .
# !pip3 install -r ./examples/requirements.txt

os.chdir('/content/transformers/examples')

# !pip3 install dict_to_obj
# !pip3 install kaggle

# %%
import torch
import run_language_modeling
import run_generation
from dict_to_obj import DictToObj
import collections
import random
import numpy as np

from transformers import AutoConfig
from transformers import AutoTokenizer
from transformers import AutoModelWithLMHead

# %%
#! kaggle datasets download -d rtatman/blog-authorship-corpus
! unzip /content/transformers/examples/blog-authorship-corpus.zip
# Out:
# Archive:  /content/transformers/examples/blog-authorship-corpus.zip
#   inflating: blogtext.csv

# %% [markdown]
# ### Mount your Google Drive
# We will be saving trained checkpoints on your Google Drive so that they can be accessed even if the Colab session dies. Make sure to login with your UPenn credentials, as you will be saving several gigabytes of data, and Penn gives you unlimited Drive storage.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Download presidential speech data.
# It's already been split into a train, valid, and test set for you.

# %%
import pandas as pd
df = pd.read_csv("blogtext.csv")
data = df["text"].tolist()
with open("/content/presidential_speeches_train.txt", "w") as f:
    for data in data[:8000]:
        f.writelines(data + "\n")
with open("/content/presidential_speeches_valid.txt", "w") as f:
    for data in data[8000:9000]:
        f.writelines(data + "\n")
with open("/content/presidential_speeches_test.txt", "w") as f:
    for data in data[9000:10000]:
        f.writelines(data + "\n")

# %%
# Download the train and test set.
# !wget -nc -O /content/presidential_speeches_test.txt https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class.github.io/master/homeworks/language-model/presidential_speeches_test.txt
# !wget -nc -O /content/presidential_speeches_valid.txt https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class.github.io/master/homeworks/language-model/presidential_speeches_valid.txt
# !wget -nc -O /content/presidential_speeches_train.txt https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class.github.io/master/homeworks/language-model/presidential_speeches_train.txt
# Out:
# --2020-04-10 03:28:15--  https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class.github.io/master/homeworks/language-model/presidential_speeches_test.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 622537 (608K) [text/plain]
# Saving to: ‘/content/presidential_speeches_test.txt’
#
# /content/presidenti 100%[===================>] 607.95K  --.-KB/s    in 0.01s
#
# 2020-04-10 03:28:15 (61.2 MB/s) - ‘/content/presidential_speeches_test.txt’ saved [622537/622537]
#
# --2020-04-10 03:28:16--  https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class.github.io/master/homeworks/language-model/presidential_speeches_valid.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1117165 (1.1M) [text/plain]
# Saving to: ‘/content/presidential_speeches_valid.txt’
#
# /content/presidenti 100%[===================>]   1.06M  --.-KB/s    in 0.01s
#
# 2020-04-10 03:28:16 (102 MB/s) - ‘/content/presidential_speeches_valid.txt’ saved [1117165/1117165]
#
# --2020-04-10 03:28:17--  https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class.github.io/master/homeworks/language-model/presidential_speeches_train.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20269025 (19M) [text/plain]
# Saving to: ‘/content/presidential_speeches_train.txt’
#
# /content/presidenti 100%[===================>]  19.33M  --.-KB/s    in 0.1s
#
# 2020-04-10 03:28:17 (142 MB/s) - ‘/content/presidential_speeches_train.txt’ saved [20269025/20269025]

# %% [markdown]
# ## Finetune and Eval
# The Hugging Face library provides a script [run_language_modeling.py](https://github.com/huggingface/transformers/blob/master/examples/run_language_modeling.py) which contains all of the code for training and evaluating a language model.
#
# We will be calling this script directly from the command line in order to launch training. We will also use functions from this script to conduct evaluation and generate samples at inference time.

# %% [markdown]
# ### Launch fine-tuninng
# We will be calling `run_language_modeling.py` from the command line to launch fine-tuning, **Running fine-tuning may take several hours.** Every `save_steps` steps, a checkpoint is saved to disk. The checkpoint contains all the learned weights for your model, and you can  always reload the model from a saved checkpoint, even if your Colab has crashed.
#
# Below is an explanation of some of the arguments you might want to modify in the command below.
#
# * `--line_by_line`: Add `--line_by_line` if distinct lines of the text should be treated as distinct training examples. For example, if your dataset contains one story/tweet/article per line, this should be set.
# * `--num_train_epochs`: The number of times to iterate over the train set. Increasing the number of epochs may result in better performance, but making this number too high will cause the model to overfit on the train set.
# * `--block_size`: Your training text is truncated into blocks of this length. At test time, you will only want to generate sequences that are at most this length.
# * `--gradient_accumulation_steps`: Update the model weights every this many steps. You shold set this to >1 when the batch size is very small to improve training stability.
# * `--output_dir`: This is the where checkpoints will get saved. When you finetune on your own dataset, you should change this path. We recommend saving checkpoints to your Google Drive (`/content/drive/My Drive/`) so you can access them even if the Colab session dies.
# * `--model_name_or_path` The path to the model weights to use when starting fine-tuning. You can set this to `gpt2-medium` to initialize with GPT-2's 355 million parameter model, or `gpt2` to initialize with their smaller 124 million parameter model. You can also set this to one of your own checkpoints to restart your training job if it crashes.
#
# **I am getting out-of memory errors. What do I do?**
#
# The number of trainable paramters in the model is a function of the `block_size` and the `batch_size`. If you are getting out-of-memory errors, then try drecreasing these value.
#
# **Oh no! My computer went to sleep and the Colab disconnected.**
#
# The train job might have still completed. Check the `output_dir` in your Google Drive to see if checkpoint files have been created there.
#
# **Training is taking foreverrrrrr.**
#
# Try decreasing `num_train_epochs` or changing `model_name_or_path` to `gpt2` instead of `gpt2-medium`.
# If your evaluation set is very large, you might also want to remove the `evaluate_during_training` flag or increase `logging_steps`.

# %%
# !python run_language_modeling.py \
    --output_dir='/content/drive/My Drive/finetuned_models/presidential_speeches' \
    --model_type=gpt2 \
    --model_name_or_path=gpt2-medium \
    --save_total_limit=5 \
    --num_train_epochs=2.0 \
    --do_train \
    --evaluate_during_training \
    --logging_steps=500 \
    --save_steps=500 \
    --train_data_file=/content/presidential_speeches_train.txt \
    --do_eval \
    --eval_data_file=/content/presidential_speeches_valid.txt \
    --per_gpu_train_batch_size=2 \
    --per_gpu_eval_batch_size=2 \
    --block_size=128 \
    --gradient_accumulation_steps=5
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration:  30% 2086/7038 [13:51<30:30,  2.71it/s]
# Iteration:  30% 2087/7038 [13:51<29:09,  2.83it/s]
# Iteration:  30% 2088/7038 [13:52<28:16,  2.92it/s]
# Iteration:  30% 2089/7038 [13:52<27:25,  3.01it/s]
# Iteration:  30% 2090/7038 [13:52<32:08,  2.57it/s]
# Iteration:  30% 2091/7038 [13:53<30:20,  2.72it/s]
# Iteration:  30% 2092/7038 [13:53<28:56,  2.85it/s]
# Iteration:  30% 2093/7038 [13:53<28:02,  2.94it/s]
# Iteration:  30% 2094/7038 [13:54<27:28,  3.00it/s]
# Iteration:  30% 2095/7038 [13:54<32:20,  2.55it/s]
# Iteration:  30% 2096/7038 [13:55<30:31,  2.70it/s]
# Iteration:  30% 2097/7038 [13:55<29:11,  2.82it/s]
# Iteration:  30% 2098/7038 [13:55<28:12,  2.92it/s]
# Iteration:  30% 2099/7038 [13:56<27:27,  3.00it/s]
# Iteration:  30% 2100/7038 [13:56<32:13,  2.55it/s]
# Iteration:  30% 2101/7038 [13:56<30:27,  2.70it/s]
# Iteration:  30% 2102/7038 [13:57<29:10,  2.82it/s]
# Iteration:  30% 2103/7038 [13:57<28:15,  2.91it/s]
# Iteration:  30% 2104/7038 [13:57<27:22,  3.00it/s]
# Iteration:  30% 2105/7038 [13:58<32:11,  2.55it/s]
# Iteration:  30% 2106/7038 [13:58<30:23,  2.70it/s]
# Iteration:  30% 2107/7038 [13:58<29:01,  2.83it/s]
# Iteration:  30% 2108/7038 [13:59<28:06,  2.92it/s]
# Iteration:  30% 2109/7038 [13:59<27:18,  3.01it/s]
# Iteration:  30% 2110/7038 [14:00<32:08,  2.56it/s]
# Iteration:  30% 2111/7038 [14:00<30:25,  2.70it/s]
# Iteration:  30% 2112/7038 [14:00<28:50,  2.85it/s]
# Iteration:  30% 2113/7038 [14:01<28:01,  2.93it/s]
# Iteration:  30% 2114/7038 [14:01<27:16,  3.01it/s]
# Iteration:  30% 2115/7038 [14:01<32:01,  2.56it/s]
# Iteration:  30% 2116/7038 [14:02<30:25,  2.70it/s]
# Iteration:  30% 2117/7038 [14:02<28:59,  2.83it/s]
# Iteration:  30% 2118/7038 [14:02<27:53,  2.94it/s]
# Iteration:  30% 2119/7038 [14:03<27:07,  3.02it/s]
# Iteration:  30% 2120/7038 [14:03<31:56,  2.57it/s]
# Iteration:  30% 2121/7038 [14:04<30:10,  2.72it/s]
# Iteration:  30% 2122/7038 [14:04<28:49,  2.84it/s]
# Iteration:  30% 2123/7038 [14:04<27:52,  2.94it/s]
# Iteration:  30% 2124/7038 [14:04<27:03,  3.03it/s]
# Iteration:  30% 2125/7038 [14:05<31:48,  2.57it/s]
# Iteration:  30% 2126/7038 [14:05<30:00,  2.73it/s]
# Iteration:  30% 2127/7038 [14:06<28:36,  2.86it/s]
# Iteration:  30% 2128/7038 [14:06<27:48,  2.94it/s]
# Iteration:  30% 2129/7038 [14:06<27:16,  3.00it/s]
# Iteration:  30% 2130/7038 [14:07<31:59,  2.56it/s]
# Iteration:  30% 2131/7038 [14:07<30:08,  2.71it/s]
# Iteration:  30% 2132/7038 [14:07<28:42,  2.85it/s]
# Iteration:  30% 2133/7038 [14:08<27:56,  2.93it/s]
# Iteration:  30% 2134/7038 [14:08<27:13,  3.00it/s]
# Iteration:  30% 2135/7038 [14:09<31:57,  2.56it/s]
# Iteration:  30% 2136/7038 [14:09<30:04,  2.72it/s]
# Iteration:  30% 2137/7038 [14:09<28:44,  2.84it/s]
# Iteration:  30% 2138/7038 [14:09<27:41,  2.95it/s]
# Iteration:  30% 2139/7038 [14:10<26:57,  3.03it/s]
# Iteration:  30% 2140/7038 [14:10<31:52,  2.56it/s]
# Iteration:  30% 2141/7038 [14:11<30:12,  2.70it/s]
# Iteration:  30% 2142/7038 [14:11<28:43,  2.84it/s]
# Iteration:  30% 2143/7038 [14:11<27:52,  2.93it/s]
# Iteration:  30% 2144/7038 [14:12<27:16,  2.99it/s]
# Iteration:  30% 2145/7038 [14:12<31:59,  2.55it/s]
# Iteration:  30% 2146/7038 [14:12<30:03,  2.71it/s]
# Iteration:  31% 2147/7038 [14:13<28:39,  2.84it/s]
# Iteration:  31% 2148/7038 [14:13<27:42,  2.94it/s]
# Iteration:  31% 2149/7038 [14:13<27:07,  3.00it/s]
# Iteration:  31% 2150/7038 [14:14<31:49,  2.56it/s]
# Iteration:  31% 2151/7038 [14:14<30:04,  2.71it/s]
# Iteration:  31% 2152/7038 [14:15<28:37,  2.85it/s]
# Iteration:  31% 2153/7038 [14:15<27:46,  2.93it/s]
# Iteration:  31% 2154/7038 [14:15<27:04,  3.01it/s]
# Iteration:  31% 2155/7038 [14:16<31:50,  2.56it/s]
# Iteration:  31% 2156/7038 [14:16<30:03,  2.71it/s]
# Iteration:  31% 2157/7038 [14:16<28:40,  2.84it/s]
# Iteration:  31% 2158/7038 [14:17<27:34,  2.95it/s]
# Iteration:  31% 2159/7038 [14:17<26:50,  3.03it/s]
# Iteration:  31% 2160/7038 [14:17<31:35,  2.57it/s]
# Iteration:  31% 2161/7038 [14:18<29:47,  2.73it/s]
# Iteration:  31% 2162/7038 [14:18<28:25,  2.86it/s]
# Iteration:  31% 2163/7038 [14:18<27:22,  2.97it/s]
# Iteration:  31% 2164/7038 [14:19<26:46,  3.03it/s]
# Iteration:  31% 2165/7038 [14:19<31:29,  2.58it/s]
# Iteration:  31% 2166/7038 [14:20<29:45,  2.73it/s]
# Iteration:  31% 2167/7038 [14:20<28:24,  2.86it/s]
# Iteration:  31% 2168/7038 [14:20<27:40,  2.93it/s]
# Iteration:  31% 2169/7038 [14:21<27:19,  2.97it/s]
# Iteration:  31% 2170/7038 [14:21<32:08,  2.52it/s]
# Iteration:  31% 2171/7038 [14:21<30:15,  2.68it/s]
# Iteration:  31% 2172/7038 [14:22<28:48,  2.82it/s]
# Iteration:  31% 2173/7038 [14:22<27:54,  2.91it/s]
# Iteration:  31% 2174/7038 [14:22<27:15,  2.97it/s]
# Iteration:  31% 2175/7038 [14:23<31:52,  2.54it/s]
# Iteration:  31% 2176/7038 [14:23<30:01,  2.70it/s]
# Iteration:  31% 2177/7038 [14:23<28:36,  2.83it/s]
# Iteration:  31% 2178/7038 [14:24<27:32,  2.94it/s]
# Iteration:  31% 2179/7038 [14:24<26:46,  3.02it/s]
# Iteration:  31% 2180/7038 [14:25<31:33,  2.57it/s]
# Iteration:  31% 2181/7038 [14:25<29:50,  2.71it/s]
# Iteration:  31% 2182/7038 [14:25<28:28,  2.84it/s]
# Iteration:  31% 2183/7038 [14:26<27:29,  2.94it/s]
# Iteration:  31% 2184/7038 [14:26<26:53,  3.01it/s]
# Iteration:  31% 2185/7038 [14:26<31:54,  2.54it/s]
# Iteration:  31% 2186/7038 [14:27<30:04,  2.69it/s]
# Iteration:  31% 2187/7038 [14:27<28:37,  2.82it/s]
# Iteration:  31% 2188/7038 [14:27<27:33,  2.93it/s]
# Iteration:  31% 2189/7038 [14:28<26:46,  3.02it/s]
# Iteration:  31% 2190/7038 [14:28<31:27,  2.57it/s]
# Iteration:  31% 2191/7038 [14:29<29:46,  2.71it/s]
# Iteration:  31% 2192/7038 [14:29<28:25,  2.84it/s]
# Iteration:  31% 2193/7038 [14:29<27:23,  2.95it/s]
# Iteration:  31% 2194/7038 [14:29<26:49,  3.01it/s]
# Iteration:  31% 2195/7038 [14:30<31:33,  2.56it/s]
# Iteration:  31% 2196/7038 [14:30<29:46,  2.71it/s]
# Iteration:  31% 2197/7038 [14:31<28:23,  2.84it/s]
# Iteration:  31% 2198/7038 [14:31<27:25,  2.94it/s]
# Iteration:  31% 2199/7038 [14:31<26:51,  3.00it/s]
# Iteration:  31% 2200/7038 [14:32<31:52,  2.53it/s]
# Iteration:  31% 2201/7038 [14:32<30:01,  2.68it/s]
# Iteration:  31% 2202/7038 [14:32<28:38,  2.81it/s]
# Iteration:  31% 2203/7038 [14:33<27:42,  2.91it/s]
# Iteration:  31% 2204/7038 [14:33<26:51,  3.00it/s]
# Iteration:  31% 2205/7038 [14:34<31:39,  2.54it/s]
# Iteration:  31% 2206/7038 [14:34<29:57,  2.69it/s]
# Iteration:  31% 2207/7038 [14:34<28:29,  2.83it/s]
# Iteration:  31% 2208/7038 [14:35<27:31,  2.93it/s]
# Iteration:  31% 2209/7038 [14:35<26:41,  3.01it/s]
# Iteration:  31% 2210/7038 [14:35<31:22,  2.56it/s]
# Iteration:  31% 2211/7038 [14:36<29:34,  2.72it/s]
# Iteration:  31% 2212/7038 [14:36<28:13,  2.85it/s]
# Iteration:  31% 2213/7038 [14:36<27:16,  2.95it/s]
# Iteration:  31% 2214/7038 [14:37<26:48,  3.00it/s]
# Iteration:  31% 2215/7038 [14:37<31:24,  2.56it/s]
# Iteration:  31% 2216/7038 [14:37<29:37,  2.71it/s]
# Iteration:  32% 2217/7038 [14:38<28:18,  2.84it/s]
# Iteration:  32% 2218/7038 [14:38<27:18,  2.94it/s]
# Iteration:  32% 2219/7038 [14:38<26:35,  3.02it/s]
# Iteration:  32% 2220/7038 [14:39<31:16,  2.57it/s]
# Iteration:  32% 2221/7038 [14:39<29:31,  2.72it/s]
# Iteration:  32% 2222/7038 [14:40<28:18,  2.84it/s]
# Iteration:  32% 2223/7038 [14:40<27:21,  2.93it/s]
# Iteration:  32% 2224/7038 [14:40<26:37,  3.01it/s]
# Iteration:  32% 2225/7038 [14:41<31:22,  2.56it/s]
# Iteration:  32% 2226/7038 [14:41<29:33,  2.71it/s]
# Iteration:  32% 2227/7038 [14:41<28:09,  2.85it/s]
# Iteration:  32% 2228/7038 [14:42<27:09,  2.95it/s]
# Iteration:  32% 2229/7038 [14:42<26:39,  3.01it/s]
# Iteration:  32% 2230/7038 [14:42<31:30,  2.54it/s]
# Iteration:  32% 2231/7038 [14:43<29:43,  2.69it/s]
# Iteration:  32% 2232/7038 [14:43<28:15,  2.84it/s]
# Iteration:  32% 2233/7038 [14:43<27:24,  2.92it/s]
# Iteration:  32% 2234/7038 [14:44<26:44,  2.99it/s]
# Iteration:  32% 2235/7038 [14:44<31:17,  2.56it/s]
# Iteration:  32% 2236/7038 [14:45<29:31,  2.71it/s]
# Iteration:  32% 2237/7038 [14:45<28:16,  2.83it/s]
# Iteration:  32% 2238/7038 [14:45<27:10,  2.94it/s]
# Iteration:  32% 2239/7038 [14:46<26:43,  2.99it/s]
# Iteration:  32% 2240/7038 [14:46<31:16,  2.56it/s]
# Iteration:  32% 2241/7038 [14:46<29:31,  2.71it/s]
# Iteration:  32% 2242/7038 [14:47<28:08,  2.84it/s]
# Iteration:  32% 2243/7038 [14:47<27:10,  2.94it/s]
# Iteration:  32% 2244/7038 [14:47<26:28,  3.02it/s]
# Iteration:  32% 2245/7038 [14:48<31:06,  2.57it/s]
# Iteration:  32% 2246/7038 [14:48<29:23,  2.72it/s]
# Iteration:  32% 2247/7038 [14:48<27:56,  2.86it/s]
# Iteration:  32% 2248/7038 [14:49<26:56,  2.96it/s]
# Iteration:  32% 2249/7038 [14:49<26:15,  3.04it/s]
# Iteration:  32% 2250/7038 [14:50<30:55,  2.58it/s]
# Iteration:  32% 2251/7038 [14:50<29:10,  2.74it/s]
# Iteration:  32% 2252/7038 [14:50<27:46,  2.87it/s]
# Iteration:  32% 2253/7038 [14:51<26:54,  2.96it/s]
# Iteration:  32% 2254/7038 [14:51<26:20,  3.03it/s]
# Iteration:  32% 2255/7038 [14:51<31:03,  2.57it/s]
# Iteration:  32% 2256/7038 [14:52<29:23,  2.71it/s]
# Iteration:  32% 2257/7038 [14:52<27:59,  2.85it/s]
# Iteration:  32% 2258/7038 [14:52<26:58,  2.95it/s]
# Iteration:  32% 2259/7038 [14:53<26:25,  3.01it/s]
# Iteration:  32% 2260/7038 [14:53<31:13,  2.55it/s]
# Iteration:  32% 2261/7038 [14:53<29:24,  2.71it/s]
# Iteration:  32% 2262/7038 [14:54<28:02,  2.84it/s]
# Iteration:  32% 2263/7038 [14:54<27:00,  2.95it/s]
# Iteration:  32% 2264/7038 [14:54<26:20,  3.02it/s]
# Iteration:  32% 2265/7038 [14:55<31:02,  2.56it/s]
# Iteration:  32% 2266/7038 [14:55<29:16,  2.72it/s]
# Iteration:  32% 2267/7038 [14:56<27:55,  2.85it/s]
# Iteration:  32% 2268/7038 [14:56<26:57,  2.95it/s]
# Iteration:  32% 2269/7038 [14:56<26:18,  3.02it/s]
# Iteration:  32% 2270/7038 [14:57<31:05,  2.56it/s]
# Iteration:  32% 2271/7038 [14:57<29:24,  2.70it/s]
# Iteration:  32% 2272/7038 [14:57<28:01,  2.83it/s]
# Iteration:  32% 2273/7038 [14:58<27:02,  2.94it/s]
# Iteration:  32% 2274/7038 [14:58<26:22,  3.01it/s]
# Iteration:  32% 2275/7038 [14:59<31:05,  2.55it/s]
# Iteration:  32% 2276/7038 [14:59<29:29,  2.69it/s]
# Iteration:  32% 2277/7038 [14:59<28:02,  2.83it/s]
# Iteration:  32% 2278/7038 [14:59<27:06,  2.93it/s]
# Iteration:  32% 2279/7038 [15:00<26:21,  3.01it/s]
# Iteration:  32% 2280/7038 [15:00<31:06,  2.55it/s]
# Iteration:  32% 2281/7038 [15:01<29:18,  2.70it/s]
# Iteration:  32% 2282/7038 [15:01<27:57,  2.84it/s]
# Iteration:  32% 2283/7038 [15:01<26:53,  2.95it/s]
# Iteration:  32% 2284/7038 [15:02<26:13,  3.02it/s]
# Iteration:  32% 2285/7038 [15:02<30:51,  2.57it/s]
# Iteration:  32% 2286/7038 [15:02<29:07,  2.72it/s]
# Iteration:  32% 2287/7038 [15:03<28:05,  2.82it/s]
# Iteration:  33% 2288/7038 [15:03<26:58,  2.93it/s]
# Iteration:  33% 2289/7038 [15:03<26:30,  2.99it/s]
# Iteration:  33% 2290/7038 [15:04<31:07,  2.54it/s]
# Iteration:  33% 2291/7038 [15:04<29:35,  2.67it/s]
# Iteration:  33% 2292/7038 [15:05<28:02,  2.82it/s]
# Iteration:  33% 2293/7038 [15:05<26:59,  2.93it/s]
# Iteration:  33% 2294/7038 [15:05<26:15,  3.01it/s]
# Iteration:  33% 2295/7038 [15:06<30:53,  2.56it/s]
# Iteration:  33% 2296/7038 [15:06<29:19,  2.69it/s]
# Iteration:  33% 2297/7038 [15:06<27:55,  2.83it/s]
# Iteration:  33% 2298/7038 [15:07<26:56,  2.93it/s]
# Iteration:  33% 2299/7038 [15:07<26:12,  3.01it/s]
# Iteration:  33% 2300/7038 [15:07<30:51,  2.56it/s]
# Iteration:  33% 2301/7038 [15:08<29:15,  2.70it/s]
# Iteration:  33% 2302/7038 [15:08<27:47,  2.84it/s]
# Iteration:  33% 2303/7038 [15:08<26:52,  2.94it/s]
# Iteration:  33% 2304/7038 [15:09<26:09,  3.02it/s]
# Iteration:  33% 2305/7038 [15:09<30:54,  2.55it/s]
# Iteration:  33% 2306/7038 [15:10<29:25,  2.68it/s]
# Iteration:  33% 2307/7038 [15:10<27:57,  2.82it/s]
# Iteration:  33% 2308/7038 [15:10<26:51,  2.94it/s]
# Iteration:  33% 2309/7038 [15:11<26:07,  3.02it/s]
# Iteration:  33% 2310/7038 [15:11<30:47,  2.56it/s]
# Iteration:  33% 2311/7038 [15:11<29:08,  2.70it/s]
# Iteration:  33% 2312/7038 [15:12<27:45,  2.84it/s]
# Iteration:  33% 2313/7038 [15:12<26:44,  2.94it/s]
# Iteration:  33% 2314/7038 [15:12<26:00,  3.03it/s]
# Iteration:  33% 2315/7038 [15:13<30:42,  2.56it/s]
# Iteration:  33% 2316/7038 [15:13<28:59,  2.71it/s]
# Iteration:  33% 2317/7038 [15:13<27:40,  2.84it/s]
# Iteration:  33% 2318/7038 [15:14<26:47,  2.94it/s]
# Iteration:  33% 2319/7038 [15:14<26:01,  3.02it/s]
# Iteration:  33% 2320/7038 [15:15<30:52,  2.55it/s]
# Iteration:  33% 2321/7038 [15:15<29:08,  2.70it/s]
# Iteration:  33% 2322/7038 [15:15<27:40,  2.84it/s]
# Iteration:  33% 2323/7038 [15:16<26:39,  2.95it/s]
# Iteration:  33% 2324/7038 [15:16<25:53,  3.03it/s]
# Iteration:  33% 2325/7038 [15:16<30:33,  2.57it/s]
# Iteration:  33% 2326/7038 [15:17<28:52,  2.72it/s]
# Iteration:  33% 2327/7038 [15:17<27:44,  2.83it/s]
# Iteration:  33% 2328/7038 [15:17<26:38,  2.95it/s]
# Iteration:  33% 2329/7038 [15:18<26:02,  3.01it/s]
# Iteration:  33% 2330/7038 [15:18<30:36,  2.56it/s]
# Iteration:  33% 2331/7038 [15:18<28:59,  2.71it/s]
# Iteration:  33% 2332/7038 [15:19<27:47,  2.82it/s]
# Iteration:  33% 2333/7038 [15:19<26:53,  2.92it/s]
# Iteration:  33% 2334/7038 [15:19<26:15,  2.99it/s]
# Iteration:  33% 2335/7038 [15:20<30:46,  2.55it/s]
# Iteration:  33% 2336/7038 [15:20<29:15,  2.68it/s]
# Iteration:  33% 2337/7038 [15:21<27:53,  2.81it/s]
# Iteration:  33% 2338/7038 [15:21<26:48,  2.92it/s]
# Iteration:  33% 2339/7038 [15:21<26:02,  3.01it/s]
# Iteration:  33% 2340/7038 [15:22<30:42,  2.55it/s]
# Iteration:  33% 2341/7038 [15:22<28:56,  2.71it/s]
# Iteration:  33% 2342/7038 [15:22<27:33,  2.84it/s]
# Iteration:  33% 2343/7038 [15:23<26:39,  2.94it/s]
# Iteration:  33% 2344/7038 [15:23<26:04,  3.00it/s]
# Iteration:  33% 2345/7038 [15:24<30:40,  2.55it/s]
# Iteration:  33% 2346/7038 [15:24<29:03,  2.69it/s]
# Iteration:  33% 2347/7038 [15:24<27:44,  2.82it/s]
# Iteration:  33% 2348/7038 [15:25<26:49,  2.91it/s]
# Iteration:  33% 2349/7038 [15:25<26:14,  2.98it/s]
# Iteration:  33% 2350/7038 [15:25<30:50,  2.53it/s]
# Iteration:  33% 2351/7038 [15:26<29:14,  2.67it/s]
# Iteration:  33% 2352/7038 [15:26<27:48,  2.81it/s]
# Iteration:  33% 2353/7038 [15:26<26:59,  2.89it/s]
# Iteration:  33% 2354/7038 [15:27<26:12,  2.98it/s]
# Iteration:  33% 2355/7038 [15:27<30:53,  2.53it/s]
# Iteration:  33% 2356/7038 [15:27<29:01,  2.69it/s]
# Iteration:  33% 2357/7038 [15:28<27:37,  2.82it/s]
# Iteration:  34% 2358/7038 [15:28<26:35,  2.93it/s]
# Iteration:  34% 2359/7038 [15:28<25:57,  3.00it/s]
# Iteration:  34% 2360/7038 [15:29<30:43,  2.54it/s]
# Iteration:  34% 2361/7038 [15:29<28:58,  2.69it/s]
# Iteration:  34% 2362/7038 [15:30<27:34,  2.83it/s]
# Iteration:  34% 2363/7038 [15:30<26:34,  2.93it/s]
# Iteration:  34% 2364/7038 [15:30<25:54,  3.01it/s]
# Iteration:  34% 2365/7038 [15:31<30:45,  2.53it/s]
# Iteration:  34% 2366/7038 [15:31<29:04,  2.68it/s]
# Iteration:  34% 2367/7038 [15:31<27:33,  2.82it/s]
# Iteration:  34% 2368/7038 [15:32<26:48,  2.90it/s]
# Iteration:  34% 2369/7038 [15:32<26:19,  2.96it/s]
# Iteration:  34% 2370/7038 [15:33<30:52,  2.52it/s]
# Iteration:  34% 2371/7038 [15:33<29:09,  2.67it/s]
# Iteration:  34% 2372/7038 [15:33<27:53,  2.79it/s]
# Iteration:  34% 2373/7038 [15:34<26:49,  2.90it/s]
# Iteration:  34% 2374/7038 [15:34<26:10,  2.97it/s]
# Iteration:  34% 2375/7038 [15:34<30:56,  2.51it/s]
# Iteration:  34% 2376/7038 [15:35<29:13,  2.66it/s]
# Iteration:  34% 2377/7038 [15:35<27:41,  2.80it/s]
# Iteration:  34% 2378/7038 [15:35<26:34,  2.92it/s]
# Iteration:  34% 2379/7038 [15:36<25:52,  3.00it/s]
# Iteration:  34% 2380/7038 [15:36<30:23,  2.55it/s]
# Iteration:  34% 2381/7038 [15:36<28:41,  2.71it/s]
# Iteration:  34% 2382/7038 [15:37<27:21,  2.84it/s]
# Iteration:  34% 2383/7038 [15:37<26:26,  2.93it/s]
# Iteration:  34% 2384/7038 [15:37<25:39,  3.02it/s]
# Iteration:  34% 2385/7038 [15:38<30:21,  2.55it/s]
# Iteration:  34% 2386/7038 [15:38<28:34,  2.71it/s]
# Iteration:  34% 2387/7038 [15:39<27:18,  2.84it/s]
# Iteration:  34% 2388/7038 [15:39<26:17,  2.95it/s]
# Iteration:  34% 2389/7038 [15:39<25:38,  3.02it/s]
# Iteration:  34% 2390/7038 [15:40<30:15,  2.56it/s]
# Iteration:  34% 2391/7038 [15:40<29:08,  2.66it/s]
# Iteration:  34% 2392/7038 [15:40<28:12,  2.74it/s]
# Iteration:  34% 2393/7038 [15:41<27:52,  2.78it/s]
# Iteration:  34% 2394/7038 [15:41<27:23,  2.83it/s]
# Iteration:  34% 2395/7038 [15:42<31:57,  2.42it/s]
# Iteration:  34% 2396/7038 [15:42<30:11,  2.56it/s]
# Iteration:  34% 2397/7038 [15:42<28:37,  2.70it/s]
# Iteration:  34% 2398/7038 [15:43<27:40,  2.79it/s]
# Iteration:  34% 2399/7038 [15:43<27:04,  2.86it/s]
# Iteration:  34% 2400/7038 [15:44<31:52,  2.42it/s]
# Iteration:  34% 2401/7038 [15:44<29:52,  2.59it/s]
# Iteration:  34% 2402/7038 [15:44<28:26,  2.72it/s]
# Iteration:  34% 2403/7038 [15:45<27:30,  2.81it/s]
# Iteration:  34% 2404/7038 [15:45<26:56,  2.87it/s]
# Iteration:  34% 2405/7038 [15:45<31:35,  2.44it/s]
# Iteration:  34% 2406/7038 [15:46<29:51,  2.59it/s]
# Iteration:  34% 2407/7038 [15:46<28:30,  2.71it/s]
# Iteration:  34% 2408/7038 [15:46<27:26,  2.81it/s]
# Iteration:  34% 2409/7038 [15:47<26:50,  2.87it/s]
# Iteration:  34% 2410/7038 [15:47<31:28,  2.45it/s]
# Iteration:  34% 2411/7038 [15:48<29:40,  2.60it/s]
# Iteration:  34% 2412/7038 [15:48<28:23,  2.72it/s]
# Iteration:  34% 2413/7038 [15:48<27:51,  2.77it/s]
# Iteration:  34% 2414/7038 [15:49<27:05,  2.84it/s]
# Iteration:  34% 2415/7038 [15:49<31:34,  2.44it/s]
# Iteration:  34% 2416/7038 [15:49<29:48,  2.58it/s]
# Iteration:  34% 2417/7038 [15:50<28:27,  2.71it/s]
# Iteration:  34% 2418/7038 [15:50<27:23,  2.81it/s]
# Iteration:  34% 2419/7038 [15:50<26:34,  2.90it/s]
# Iteration:  34% 2420/7038 [15:51<31:25,  2.45it/s]
# Iteration:  34% 2421/7038 [15:51<29:54,  2.57it/s]
# Iteration:  34% 2422/7038 [15:52<28:24,  2.71it/s]
# Iteration:  34% 2423/7038 [15:52<27:32,  2.79it/s]
# Iteration:  34% 2424/7038 [15:52<27:07,  2.84it/s]
# Iteration:  34% 2425/7038 [15:53<31:37,  2.43it/s]
# Iteration:  34% 2426/7038 [15:53<29:49,  2.58it/s]
# Iteration:  34% 2427/7038 [15:54<28:29,  2.70it/s]
# Iteration:  34% 2428/7038 [15:54<27:31,  2.79it/s]
# Iteration:  35% 2429/7038 [15:54<26:59,  2.85it/s]
# Iteration:  35% 2430/7038 [15:55<31:17,  2.45it/s]
# Iteration:  35% 2431/7038 [15:55<29:38,  2.59it/s]
# Iteration:  35% 2432/7038 [15:55<28:27,  2.70it/s]
# Iteration:  35% 2433/7038 [15:56<27:41,  2.77it/s]
# Iteration:  35% 2434/7038 [15:56<26:54,  2.85it/s]
# Iteration:  35% 2435/7038 [15:57<31:45,  2.42it/s]
# Iteration:  35% 2436/7038 [15:57<29:56,  2.56it/s]
# Iteration:  35% 2437/7038 [15:57<28:39,  2.68it/s]
# Iteration:  35% 2438/7038 [15:58<27:53,  2.75it/s]
# Iteration:  35% 2439/7038 [15:58<27:05,  2.83it/s]
# Iteration:  35% 2440/7038 [15:59<31:37,  2.42it/s]
# Iteration:  35% 2441/7038 [15:59<29:54,  2.56it/s]
# Iteration:  35% 2442/7038 [15:59<28:55,  2.65it/s]
# Iteration:  35% 2443/7038 [16:00<27:56,  2.74it/s]
# Iteration:  35% 2444/7038 [16:00<27:02,  2.83it/s]
# Iteration:  35% 2445/7038 [16:00<31:29,  2.43it/s]
# Iteration:  35% 2446/7038 [16:01<29:42,  2.58it/s]
# Iteration:  35% 2447/7038 [16:01<28:24,  2.69it/s]
# Iteration:  35% 2448/7038 [16:01<27:28,  2.78it/s]
# Iteration:  35% 2449/7038 [16:02<26:50,  2.85it/s]
# Iteration:  35% 2450/7038 [16:02<31:19,  2.44it/s]
# Iteration:  35% 2451/7038 [16:03<29:31,  2.59it/s]
# Iteration:  35% 2452/7038 [16:03<28:05,  2.72it/s]
# Iteration:  35% 2453/7038 [16:03<27:23,  2.79it/s]
# Iteration:  35% 2454/7038 [16:04<26:38,  2.87it/s]
# Iteration:  35% 2455/7038 [16:04<30:57,  2.47it/s]
# Iteration:  35% 2456/7038 [16:05<29:32,  2.58it/s]
# Iteration:  35% 2457/7038 [16:05<28:34,  2.67it/s]
# Iteration:  35% 2458/7038 [16:05<27:34,  2.77it/s]
# Iteration:  35% 2459/7038 [16:06<26:50,  2.84it/s]
# Iteration:  35% 2460/7038 [16:06<31:29,  2.42it/s]
# Iteration:  35% 2461/7038 [16:06<29:38,  2.57it/s]
# Iteration:  35% 2462/7038 [16:07<27:53,  2.73it/s]
# Iteration:  35% 2463/7038 [16:07<26:46,  2.85it/s]
# Iteration:  35% 2464/7038 [16:07<25:56,  2.94it/s]
# Iteration:  35% 2465/7038 [16:08<30:19,  2.51it/s]
# Iteration:  35% 2466/7038 [16:08<28:32,  2.67it/s]
# Iteration:  35% 2467/7038 [16:09<27:09,  2.81it/s]
# Iteration:  35% 2468/7038 [16:09<26:04,  2.92it/s]
# Iteration:  35% 2469/7038 [16:09<25:19,  3.01it/s]
# Iteration:  35% 2470/7038 [16:10<29:39,  2.57it/s]
# Iteration:  35% 2471/7038 [16:10<28:00,  2.72it/s]
# Iteration:  35% 2472/7038 [16:10<26:40,  2.85it/s]
# Iteration:  35% 2473/7038 [16:11<25:45,  2.95it/s]
# Iteration:  35% 2474/7038 [16:11<25:09,  3.02it/s]
# Iteration:  35% 2475/7038 [16:11<29:40,  2.56it/s]
# Iteration:  35% 2476/7038 [16:12<28:13,  2.69it/s]
# Iteration:  35% 2477/7038 [16:12<26:46,  2.84it/s]
# Iteration:  35% 2478/7038 [16:12<25:44,  2.95it/s]
# Iteration:  35% 2479/7038 [16:13<25:15,  3.01it/s]
# Iteration:  35% 2480/7038 [16:13<29:45,  2.55it/s]
# Iteration:  35% 2481/7038 [16:14<28:25,  2.67it/s]
# Iteration:  35% 2482/7038 [16:14<27:12,  2.79it/s]
# Iteration:  35% 2483/7038 [16:14<26:08,  2.90it/s]
# Iteration:  35% 2484/7038 [16:15<25:22,  2.99it/s]
# Iteration:  35% 2485/7038 [16:15<29:51,  2.54it/s]
# Iteration:  35% 2486/7038 [16:15<28:05,  2.70it/s]
# Iteration:  35% 2487/7038 [16:16<26:44,  2.84it/s]
# Iteration:  35% 2488/7038 [16:16<25:46,  2.94it/s]
# Iteration:  35% 2489/7038 [16:16<25:08,  3.02it/s]
# Iteration:  35% 2490/7038 [16:17<29:36,  2.56it/s]
# Iteration:  35% 2491/7038 [16:17<27:53,  2.72it/s]
# Iteration:  35% 2492/7038 [16:17<26:37,  2.85it/s]
# Iteration:  35% 2493/7038 [16:18<25:48,  2.94it/s]
# Iteration:  35% 2494/7038 [16:18<25:07,  3.01it/s]
# Iteration:  35% 2495/7038 [16:19<29:28,  2.57it/s]
# Iteration:  35% 2496/7038 [16:19<28:08,  2.69it/s]
# Iteration:  35% 2497/7038 [16:19<26:56,  2.81it/s]
# Iteration:  35% 2498/7038 [16:20<26:00,  2.91it/s]
# Iteration:  36% 2499/7038 [16:20<25:17,  2.99it/s]
# Iteration:  36% 2500/7038 [16:20<29:38,  2.55it/s]
# Iteration:  36% 2501/7038 [16:21<28:00,  2.70it/s]
# Iteration:  36% 2502/7038 [16:21<26:36,  2.84it/s]
# Iteration:  36% 2503/7038 [16:21<25:40,  2.94it/s]
# Iteration:  36% 2504/7038 [16:22<24:59,  3.02it/s]
# Iteration:  36% 2505/7038 [16:22<29:21,  2.57it/s]
# Iteration:  36% 2506/7038 [16:22<27:45,  2.72it/s]
# Iteration:  36% 2507/7038 [16:23<26:38,  2.83it/s]
# Iteration:  36% 2508/7038 [16:23<25:37,  2.95it/s]
# Iteration:  36% 2509/7038 [16:23<25:03,  3.01it/s]
# Iteration:  36% 2510/7038 [16:24<29:27,  2.56it/s]
# Iteration:  36% 2511/7038 [16:24<27:57,  2.70it/s]
# Iteration:  36% 2512/7038 [16:25<26:47,  2.82it/s]
# Iteration:  36% 2513/7038 [16:25<25:46,  2.93it/s]
# Iteration:  36% 2514/7038 [16:25<25:01,  3.01it/s]
# Iteration:  36% 2515/7038 [16:26<29:23,  2.57it/s]
# Iteration:  36% 2516/7038 [16:26<27:51,  2.71it/s]
# Iteration:  36% 2517/7038 [16:26<26:33,  2.84it/s]
# Iteration:  36% 2518/7038 [16:27<25:33,  2.95it/s]
# Iteration:  36% 2519/7038 [16:27<24:59,  3.01it/s]
# Iteration:  36% 2520/7038 [16:28<29:29,  2.55it/s]
# Iteration:  36% 2521/7038 [16:28<27:52,  2.70it/s]
# Iteration:  36% 2522/7038 [16:28<26:35,  2.83it/s]
# Iteration:  36% 2523/7038 [16:28<25:40,  2.93it/s]
# Iteration:  36% 2524/7038 [16:29<24:54,  3.02it/s]
# Iteration:  36% 2525/7038 [16:29<29:21,  2.56it/s]
# Iteration:  36% 2526/7038 [16:30<27:44,  2.71it/s]
# Iteration:  36% 2527/7038 [16:30<26:25,  2.84it/s]
# Iteration:  36% 2528/7038 [16:30<25:37,  2.93it/s]
# Iteration:  36% 2529/7038 [16:31<24:59,  3.01it/s]
# Iteration:  36% 2530/7038 [16:31<29:24,  2.55it/s]
# Iteration:  36% 2531/7038 [16:31<27:43,  2.71it/s]
# Iteration:  36% 2532/7038 [16:32<26:26,  2.84it/s]
# Iteration:  36% 2533/7038 [16:32<25:29,  2.94it/s]
# Iteration:  36% 2534/7038 [16:32<24:48,  3.03it/s]
# Iteration:  36% 2535/7038 [16:33<29:22,  2.56it/s]
# Iteration:  36% 2536/7038 [16:33<27:45,  2.70it/s]
# Iteration:  36% 2537/7038 [16:34<26:26,  2.84it/s]
# Iteration:  36% 2538/7038 [16:34<25:26,  2.95it/s]
# Iteration:  36% 2539/7038 [16:34<24:51,  3.02it/s]
# Iteration:  36% 2540/7038 [16:35<29:15,  2.56it/s]
# Iteration:  36% 2541/7038 [16:35<27:43,  2.70it/s]
# Iteration:  36% 2542/7038 [16:35<26:35,  2.82it/s]
# Iteration:  36% 2543/7038 [16:36<25:49,  2.90it/s]
# Iteration:  36% 2544/7038 [16:36<25:19,  2.96it/s]
# Iteration:  36% 2545/7038 [16:36<29:29,  2.54it/s]
# Iteration:  36% 2546/7038 [16:37<27:50,  2.69it/s]
# Iteration:  36% 2547/7038 [16:37<26:26,  2.83it/s]
# Iteration:  36% 2548/7038 [16:37<25:30,  2.93it/s]
# Iteration:  36% 2549/7038 [16:38<24:55,  3.00it/s]
# Iteration:  36% 2550/7038 [16:38<29:11,  2.56it/s]
# Iteration:  36% 2551/7038 [16:39<27:29,  2.72it/s]
# Iteration:  36% 2552/7038 [16:39<26:15,  2.85it/s]
# Iteration:  36% 2553/7038 [16:39<25:30,  2.93it/s]
# Iteration:  36% 2554/7038 [16:40<24:47,  3.01it/s]
# Iteration:  36% 2555/7038 [16:40<29:08,  2.56it/s]
# Iteration:  36% 2556/7038 [16:40<27:30,  2.72it/s]
# Iteration:  36% 2557/7038 [16:41<26:13,  2.85it/s]
# Iteration:  36% 2558/7038 [16:41<25:26,  2.93it/s]
# Iteration:  36% 2559/7038 [16:41<24:44,  3.02it/s]
# Iteration:  36% 2560/7038 [16:42<29:02,  2.57it/s]
# Iteration:  36% 2561/7038 [16:42<27:24,  2.72it/s]
# Iteration:  36% 2562/7038 [16:42<26:14,  2.84it/s]
# Iteration:  36% 2563/7038 [16:43<25:25,  2.93it/s]
# Iteration:  36% 2564/7038 [16:43<24:51,  3.00it/s]
# Iteration:  36% 2565/7038 [16:44<29:13,  2.55it/s]
# Iteration:  36% 2566/7038 [16:44<27:39,  2.69it/s]
# Iteration:  36% 2567/7038 [16:44<26:21,  2.83it/s]
# Iteration:  36% 2568/7038 [16:45<25:24,  2.93it/s]
# Iteration:  37% 2569/7038 [16:45<24:52,  2.99it/s]
# Iteration:  37% 2570/7038 [16:45<29:12,  2.55it/s]
# Iteration:  37% 2571/7038 [16:46<27:35,  2.70it/s]
# Iteration:  37% 2572/7038 [16:46<26:16,  2.83it/s]
# Iteration:  37% 2573/7038 [16:46<25:29,  2.92it/s]
# Iteration:  37% 2574/7038 [16:47<24:49,  3.00it/s]
# Iteration:  37% 2575/7038 [16:47<29:14,  2.54it/s]
# Iteration:  37% 2576/7038 [16:48<27:41,  2.69it/s]
# Iteration:  37% 2577/7038 [16:48<26:21,  2.82it/s]
# Iteration:  37% 2578/7038 [16:48<25:27,  2.92it/s]
# Iteration:  37% 2579/7038 [16:48<24:48,  3.00it/s]
# Iteration:  37% 2580/7038 [16:49<29:06,  2.55it/s]
# Iteration:  37% 2581/7038 [16:49<27:26,  2.71it/s]
# Iteration:  37% 2582/7038 [16:50<26:15,  2.83it/s]
# Iteration:  37% 2583/7038 [16:50<25:27,  2.92it/s]
# Iteration:  37% 2584/7038 [16:50<24:57,  2.98it/s]
# Iteration:  37% 2585/7038 [16:51<29:19,  2.53it/s]
# Iteration:  37% 2586/7038 [16:51<27:36,  2.69it/s]
# Iteration:  37% 2587/7038 [16:51<26:11,  2.83it/s]
# Iteration:  37% 2588/7038 [16:52<25:21,  2.92it/s]
# Iteration:  37% 2589/7038 [16:52<24:45,  3.00it/s]
# Iteration:  37% 2590/7038 [16:53<29:00,  2.56it/s]
# Iteration:  37% 2591/7038 [16:53<27:22,  2.71it/s]
# Iteration:  37% 2592/7038 [16:53<26:05,  2.84it/s]
# Iteration:  37% 2593/7038 [16:54<25:05,  2.95it/s]
# Iteration:  37% 2594/7038 [16:54<24:27,  3.03it/s]
# Iteration:  37% 2595/7038 [16:54<28:45,  2.58it/s]
# Iteration:  37% 2596/7038 [16:55<27:11,  2.72it/s]
# Iteration:  37% 2597/7038 [16:55<25:54,  2.86it/s]
# Iteration:  37% 2598/7038 [16:55<25:13,  2.93it/s]
# Iteration:  37% 2599/7038 [16:56<24:32,  3.01it/s]
# Iteration:  37% 2600/7038 [16:56<28:51,  2.56it/s]
# Iteration:  37% 2601/7038 [16:56<27:22,  2.70it/s]
# Iteration:  37% 2602/7038 [16:57<26:26,  2.80it/s]
# Iteration:  37% 2603/7038 [16:57<25:24,  2.91it/s]
# Iteration:  37% 2604/7038 [16:57<24:47,  2.98it/s]
# Iteration:  37% 2605/7038 [16:58<29:01,  2.55it/s]
# Iteration:  37% 2606/7038 [16:58<27:24,  2.69it/s]
# Iteration:  37% 2607/7038 [16:59<26:01,  2.84it/s]
# Iteration:  37% 2608/7038 [16:59<25:06,  2.94it/s]
# Iteration:  37% 2609/7038 [16:59<24:24,  3.03it/s]
# Iteration:  37% 2610/7038 [17:00<28:41,  2.57it/s]
# Iteration:  37% 2611/7038 [17:00<27:07,  2.72it/s]
# Iteration:  37% 2612/7038 [17:00<25:51,  2.85it/s]
# Iteration:  37% 2613/7038 [17:01<25:09,  2.93it/s]
# Iteration:  37% 2614/7038 [17:01<24:49,  2.97it/s]
# Iteration:  37% 2615/7038 [17:02<29:05,  2.53it/s]
# Iteration:  37% 2616/7038 [17:02<27:28,  2.68it/s]
# Iteration:  37% 2617/7038 [17:02<26:04,  2.83it/s]
# Iteration:  37% 2618/7038 [17:02<25:08,  2.93it/s]
# Iteration:  37% 2619/7038 [17:03<24:41,  2.98it/s]
# Iteration:  37% 2620/7038 [17:03<28:52,  2.55it/s]
# Iteration:  37% 2621/7038 [17:04<27:13,  2.70it/s]
# Iteration:  37% 2622/7038 [17:04<26:02,  2.83it/s]
# Iteration:  37% 2623/7038 [17:04<25:07,  2.93it/s]
# Iteration:  37% 2624/7038 [17:05<24:28,  3.01it/s]
# Iteration:  37% 2625/7038 [17:05<28:42,  2.56it/s]
# Iteration:  37% 2626/7038 [17:05<27:05,  2.71it/s]
# Iteration:  37% 2627/7038 [17:06<25:52,  2.84it/s]
# Iteration:  37% 2628/7038 [17:06<25:01,  2.94it/s]
# Iteration:  37% 2629/7038 [17:06<24:35,  2.99it/s]
# Iteration:  37% 2630/7038 [17:07<28:49,  2.55it/s]
# Iteration:  37% 2631/7038 [17:07<27:12,  2.70it/s]
# Iteration:  37% 2632/7038 [17:08<26:03,  2.82it/s]
# Iteration:  37% 2633/7038 [17:08<25:04,  2.93it/s]
# Iteration:  37% 2634/7038 [17:08<24:24,  3.01it/s]
# Iteration:  37% 2635/7038 [17:09<28:38,  2.56it/s]
# Iteration:  37% 2636/7038 [17:09<27:01,  2.71it/s]
# Iteration:  37% 2637/7038 [17:09<25:47,  2.84it/s]
# Iteration:  37% 2638/7038 [17:10<24:57,  2.94it/s]
# Iteration:  37% 2639/7038 [17:10<24:14,  3.02it/s]
# Iteration:  38% 2640/7038 [17:10<28:34,  2.57it/s]
# Iteration:  38% 2641/7038 [17:11<27:01,  2.71it/s]
# Iteration:  38% 2642/7038 [17:11<25:53,  2.83it/s]
# Iteration:  38% 2643/7038 [17:11<24:58,  2.93it/s]
# Iteration:  38% 2644/7038 [17:12<24:25,  3.00it/s]
# Iteration:  38% 2645/7038 [17:12<28:37,  2.56it/s]
# Iteration:  38% 2646/7038 [17:13<27:05,  2.70it/s]
# Iteration:  38% 2647/7038 [17:13<25:51,  2.83it/s]
# Iteration:  38% 2648/7038 [17:13<24:51,  2.94it/s]
# Iteration:  38% 2649/7038 [17:13<24:10,  3.03it/s]
# Iteration:  38% 2650/7038 [17:14<28:26,  2.57it/s]
# Iteration:  38% 2651/7038 [17:14<26:48,  2.73it/s]
# Iteration:  38% 2652/7038 [17:15<25:35,  2.86it/s]
# Iteration:  38% 2653/7038 [17:15<24:39,  2.96it/s]
# Iteration:  38% 2654/7038 [17:15<24:04,  3.03it/s]
# Iteration:  38% 2655/7038 [17:16<28:18,  2.58it/s]
# Iteration:  38% 2656/7038 [17:16<26:45,  2.73it/s]
# Iteration:  38% 2657/7038 [17:16<25:31,  2.86it/s]
# Iteration:  38% 2658/7038 [17:17<24:50,  2.94it/s]
# Iteration:  38% 2659/7038 [17:17<24:08,  3.02it/s]
# Iteration:  38% 2660/7038 [17:18<28:26,  2.57it/s]
# Iteration:  38% 2661/7038 [17:18<26:48,  2.72it/s]
# Iteration:  38% 2662/7038 [17:18<25:36,  2.85it/s]
# Iteration:  38% 2663/7038 [17:19<24:48,  2.94it/s]
# Iteration:  38% 2664/7038 [17:19<24:10,  3.02it/s]
# Iteration:  38% 2665/7038 [17:19<28:23,  2.57it/s]
# Iteration:  38% 2666/7038 [17:20<26:46,  2.72it/s]
# Iteration:  38% 2667/7038 [17:20<25:27,  2.86it/s]
# Iteration:  38% 2668/7038 [17:20<24:43,  2.95it/s]
# Iteration:  38% 2669/7038 [17:21<24:06,  3.02it/s]
# Iteration:  38% 2670/7038 [17:21<28:18,  2.57it/s]
# Iteration:  38% 2671/7038 [17:21<26:45,  2.72it/s]
# Iteration:  38% 2672/7038 [17:22<25:32,  2.85it/s]
# Iteration:  38% 2673/7038 [17:22<24:41,  2.95it/s]
# Iteration:  38% 2674/7038 [17:22<24:05,  3.02it/s]
# Iteration:  38% 2675/7038 [17:23<28:23,  2.56it/s]
# Iteration:  38% 2676/7038 [17:23<26:49,  2.71it/s]
# Iteration:  38% 2677/7038 [17:24<25:48,  2.82it/s]
# Iteration:  38% 2678/7038 [17:24<24:57,  2.91it/s]
# Iteration:  38% 2679/7038 [17:24<24:17,  2.99it/s]
# Iteration:  38% 2680/7038 [17:25<28:29,  2.55it/s]
# Iteration:  38% 2681/7038 [17:25<26:48,  2.71it/s]
# Iteration:  38% 2682/7038 [17:25<25:33,  2.84it/s]
# Iteration:  38% 2683/7038 [17:26<24:40,  2.94it/s]
# Iteration:  38% 2684/7038 [17:26<24:07,  3.01it/s]
# Iteration:  38% 2685/7038 [17:26<28:28,  2.55it/s]
# Iteration:  38% 2686/7038 [17:27<26:49,  2.70it/s]
# Iteration:  38% 2687/7038 [17:27<25:43,  2.82it/s]
# Iteration:  38% 2688/7038 [17:27<25:01,  2.90it/s]
# Iteration:  38% 2689/7038 [17:28<24:31,  2.96it/s]
# Iteration:  38% 2690/7038 [17:28<28:36,  2.53it/s]
# Iteration:  38% 2691/7038 [17:29<27:08,  2.67it/s]
# Iteration:  38% 2692/7038 [17:29<25:42,  2.82it/s]
# Iteration:  38% 2693/7038 [17:29<24:49,  2.92it/s]
# Iteration:  38% 2694/7038 [17:30<24:16,  2.98it/s]
# Iteration:  38% 2695/7038 [17:30<28:22,  2.55it/s]
# Iteration:  38% 2696/7038 [17:30<26:48,  2.70it/s]
# Iteration:  38% 2697/7038 [17:31<25:33,  2.83it/s]
# Iteration:  38% 2698/7038 [17:31<24:38,  2.93it/s]
# Iteration:  38% 2699/7038 [17:31<24:01,  3.01it/s]
# Iteration:  38% 2700/7038 [17:32<28:17,  2.56it/s]
# Iteration:  38% 2701/7038 [17:32<26:44,  2.70it/s]
# Iteration:  38% 2702/7038 [17:33<25:32,  2.83it/s]
# Iteration:  38% 2703/7038 [17:33<24:39,  2.93it/s]
# Iteration:  38% 2704/7038 [17:33<24:06,  3.00it/s]
# Iteration:  38% 2705/7038 [17:34<28:14,  2.56it/s]
# Iteration:  38% 2706/7038 [17:34<27:00,  2.67it/s]
# Iteration:  38% 2707/7038 [17:34<25:41,  2.81it/s]
# Iteration:  38% 2708/7038 [17:35<24:49,  2.91it/s]
# Iteration:  38% 2709/7038 [17:35<24:11,  2.98it/s]
# Iteration:  39% 2710/7038 [17:35<28:24,  2.54it/s]
# Iteration:  39% 2711/7038 [17:36<26:50,  2.69it/s]
# Iteration:  39% 2712/7038 [17:36<25:26,  2.83it/s]
# Iteration:  39% 2713/7038 [17:36<24:31,  2.94it/s]
# Iteration:  39% 2714/7038 [17:37<23:59,  3.00it/s]
# Iteration:  39% 2715/7038 [17:37<28:08,  2.56it/s]
# Iteration:  39% 2716/7038 [17:38<26:33,  2.71it/s]
# Iteration:  39% 2717/7038 [17:38<25:15,  2.85it/s]
# Iteration:  39% 2718/7038 [17:38<24:23,  2.95it/s]
# Iteration:  39% 2719/7038 [17:39<23:51,  3.02it/s]
# Iteration:  39% 2720/7038 [17:39<28:19,  2.54it/s]
# Iteration:  39% 2721/7038 [17:39<26:43,  2.69it/s]
# Iteration:  39% 2722/7038 [17:40<25:35,  2.81it/s]
# Iteration:  39% 2723/7038 [17:40<24:41,  2.91it/s]
# Iteration:  39% 2724/7038 [17:40<23:56,  3.00it/s]
# Iteration:  39% 2725/7038 [17:41<28:07,  2.56it/s]
# Iteration:  39% 2726/7038 [17:41<26:28,  2.71it/s]
# Iteration:  39% 2727/7038 [17:41<25:14,  2.85it/s]
# Iteration:  39% 2728/7038 [17:42<24:26,  2.94it/s]
# Iteration:  39% 2729/7038 [17:42<23:51,  3.01it/s]
# Iteration:  39% 2730/7038 [17:43<28:01,  2.56it/s]
# Iteration:  39% 2731/7038 [17:43<26:27,  2.71it/s]
# Iteration:  39% 2732/7038 [17:43<25:11,  2.85it/s]
# Iteration:  39% 2733/7038 [17:44<24:24,  2.94it/s]
# Iteration:  39% 2734/7038 [17:44<23:44,  3.02it/s]
# Iteration:  39% 2735/7038 [17:44<28:06,  2.55it/s]
# Iteration:  39% 2736/7038 [17:45<26:37,  2.69it/s]
# Iteration:  39% 2737/7038 [17:45<25:27,  2.82it/s]
# Iteration:  39% 2738/7038 [17:45<24:25,  2.93it/s]
# Iteration:  39% 2739/7038 [17:46<23:46,  3.01it/s]
# Iteration:  39% 2740/7038 [17:46<27:57,  2.56it/s]
# Iteration:  39% 2741/7038 [17:47<26:22,  2.72it/s]
# Iteration:  39% 2742/7038 [17:47<25:21,  2.82it/s]
# Iteration:  39% 2743/7038 [17:47<24:23,  2.93it/s]
# Iteration:  39% 2744/7038 [17:47<23:44,  3.01it/s]
# Iteration:  39% 2745/7038 [17:48<27:53,  2.57it/s]
# Iteration:  39% 2746/7038 [17:48<26:16,  2.72it/s]
# Iteration:  39% 2747/7038 [17:49<25:03,  2.85it/s]
# Iteration:  39% 2748/7038 [17:49<24:19,  2.94it/s]
# Iteration:  39% 2749/7038 [17:49<23:46,  3.01it/s]
# Iteration:  39% 2750/7038 [17:50<27:57,  2.56it/s]
# Iteration:  39% 2751/7038 [17:50<26:24,  2.71it/s]
# Iteration:  39% 2752/7038 [17:50<25:15,  2.83it/s]
# Iteration:  39% 2753/7038 [17:51<24:28,  2.92it/s]
# Iteration:  39% 2754/7038 [17:51<23:47,  3.00it/s]
# Iteration:  39% 2755/7038 [17:52<27:57,  2.55it/s]
# Iteration:  39% 2756/7038 [17:52<26:24,  2.70it/s]
# Iteration:  39% 2757/7038 [17:52<25:13,  2.83it/s]
# Iteration:  39% 2758/7038 [17:52<24:14,  2.94it/s]
# Iteration:  39% 2759/7038 [17:53<23:38,  3.02it/s]
# Iteration:  39% 2760/7038 [17:53<27:50,  2.56it/s]
# Iteration:  39% 2761/7038 [17:54<26:16,  2.71it/s]
# Iteration:  39% 2762/7038 [17:54<25:08,  2.83it/s]
# Iteration:  39% 2763/7038 [17:54<24:17,  2.93it/s]
# Iteration:  39% 2764/7038 [17:55<23:47,  2.99it/s]
# Iteration:  39% 2765/7038 [17:55<27:51,  2.56it/s]
# Iteration:  39% 2766/7038 [17:55<26:24,  2.70it/s]
# Iteration:  39% 2767/7038 [17:56<25:21,  2.81it/s]
# Iteration:  39% 2768/7038 [17:56<24:36,  2.89it/s]
# Iteration:  39% 2769/7038 [17:56<23:59,  2.97it/s]
# Iteration:  39% 2770/7038 [17:57<28:02,  2.54it/s]
# Iteration:  39% 2771/7038 [17:57<26:30,  2.68it/s]
# Iteration:  39% 2772/7038 [17:58<25:15,  2.81it/s]
# Iteration:  39% 2773/7038 [17:58<24:25,  2.91it/s]
# Iteration:  39% 2774/7038 [17:58<23:45,  2.99it/s]
# Iteration:  39% 2775/7038 [17:59<27:58,  2.54it/s]
# Iteration:  39% 2776/7038 [17:59<26:19,  2.70it/s]
# Iteration:  39% 2777/7038 [17:59<24:59,  2.84it/s]
# Iteration:  39% 2778/7038 [18:00<24:07,  2.94it/s]
# Iteration:  39% 2779/7038 [18:00<23:32,  3.02it/s]
# Iteration:  39% 2780/7038 [18:01<27:45,  2.56it/s]
# Iteration:  40% 2781/7038 [18:01<26:09,  2.71it/s]
# Iteration:  40% 2782/7038 [18:01<25:00,  2.84it/s]
# Iteration:  40% 2783/7038 [18:01<24:16,  2.92it/s]
# Iteration:  40% 2784/7038 [18:02<23:38,  3.00it/s]
# Iteration:  40% 2785/7038 [18:02<27:48,  2.55it/s]
# Iteration:  40% 2786/7038 [18:03<26:19,  2.69it/s]
# Iteration:  40% 2787/7038 [18:03<25:08,  2.82it/s]
# Iteration:  40% 2788/7038 [18:03<24:19,  2.91it/s]
# Iteration:  40% 2789/7038 [18:04<23:37,  3.00it/s]
# Iteration:  40% 2790/7038 [18:04<27:46,  2.55it/s]
# Iteration:  40% 2791/7038 [18:04<26:07,  2.71it/s]
# Iteration:  40% 2792/7038 [18:05<24:55,  2.84it/s]
# Iteration:  40% 2793/7038 [18:05<24:02,  2.94it/s]
# Iteration:  40% 2794/7038 [18:05<23:25,  3.02it/s]
# Iteration:  40% 2795/7038 [18:06<27:33,  2.57it/s]
# Iteration:  40% 2796/7038 [18:06<26:02,  2.71it/s]
# Iteration:  40% 2797/7038 [18:07<24:53,  2.84it/s]
# Iteration:  40% 2798/7038 [18:07<24:12,  2.92it/s]
# Iteration:  40% 2799/7038 [18:07<23:39,  2.99it/s]
# Iteration:  40% 2800/7038 [18:08<27:48,  2.54it/s]
# Iteration:  40% 2801/7038 [18:08<26:09,  2.70it/s]
# Iteration:  40% 2802/7038 [18:08<25:05,  2.81it/s]
# Iteration:  40% 2803/7038 [18:09<24:13,  2.91it/s]
# Iteration:  40% 2804/7038 [18:09<23:35,  2.99it/s]
# Iteration:  40% 2805/7038 [18:09<27:36,  2.56it/s]
# Iteration:  40% 2806/7038 [18:10<26:16,  2.68it/s]
# Iteration:  40% 2807/7038 [18:10<24:57,  2.82it/s]
# Iteration:  40% 2808/7038 [18:10<24:06,  2.92it/s]
# Iteration:  40% 2809/7038 [18:11<23:29,  3.00it/s]
# Iteration:  40% 2810/7038 [18:11<27:33,  2.56it/s]
# Iteration:  40% 2811/7038 [18:12<26:01,  2.71it/s]
# Iteration:  40% 2812/7038 [18:12<24:45,  2.84it/s]
# Iteration:  40% 2813/7038 [18:12<23:53,  2.95it/s]
# Iteration:  40% 2814/7038 [18:13<23:23,  3.01it/s]
# Iteration:  40% 2815/7038 [18:13<27:31,  2.56it/s]
# Iteration:  40% 2816/7038 [18:13<26:03,  2.70it/s]
# Iteration:  40% 2817/7038 [18:14<24:49,  2.83it/s]
# Iteration:  40% 2818/7038 [18:14<23:54,  2.94it/s]
# Iteration:  40% 2819/7038 [18:14<23:14,  3.03it/s]
# Iteration:  40% 2820/7038 [18:15<27:26,  2.56it/s]
# Iteration:  40% 2821/7038 [18:15<25:54,  2.71it/s]
# Iteration:  40% 2822/7038 [18:15<24:41,  2.85it/s]
# Iteration:  40% 2823/7038 [18:16<23:52,  2.94it/s]
# Iteration:  40% 2824/7038 [18:16<23:13,  3.02it/s]
# Iteration:  40% 2825/7038 [18:17<27:17,  2.57it/s]
# Iteration:  40% 2826/7038 [18:17<25:48,  2.72it/s]
# Iteration:  40% 2827/7038 [18:17<24:46,  2.83it/s]
# Iteration:  40% 2828/7038 [18:18<24:00,  2.92it/s]
# Iteration:  40% 2829/7038 [18:18<23:25,  2.99it/s]
# Iteration:  40% 2830/7038 [18:18<27:38,  2.54it/s]
# Iteration:  40% 2831/7038 [18:19<26:10,  2.68it/s]
# Iteration:  40% 2832/7038 [18:19<24:56,  2.81it/s]
# Iteration:  40% 2833/7038 [18:19<23:57,  2.93it/s]
# Iteration:  40% 2834/7038 [18:20<23:20,  3.00it/s]
# Iteration:  40% 2835/7038 [18:20<27:32,  2.54it/s]
# Iteration:  40% 2836/7038 [18:21<25:54,  2.70it/s]
# Iteration:  40% 2837/7038 [18:21<24:39,  2.84it/s]
# Iteration:  40% 2838/7038 [18:21<23:45,  2.95it/s]
# Iteration:  40% 2839/7038 [18:21<23:04,  3.03it/s]
# Iteration:  40% 2840/7038 [18:22<27:18,  2.56it/s]
# Iteration:  40% 2841/7038 [18:22<25:53,  2.70it/s]
# Iteration:  40% 2842/7038 [18:23<24:35,  2.84it/s]
# Iteration:  40% 2843/7038 [18:23<23:41,  2.95it/s]
# Iteration:  40% 2844/7038 [18:23<23:20,  2.99it/s]
# Iteration:  40% 2845/7038 [18:24<27:26,  2.55it/s]
# Iteration:  40% 2846/7038 [18:24<25:54,  2.70it/s]
# Iteration:  40% 2847/7038 [18:24<24:44,  2.82it/s]
# Iteration:  40% 2848/7038 [18:25<23:53,  2.92it/s]
# Iteration:  40% 2849/7038 [18:25<23:11,  3.01it/s]
# Iteration:  40% 2850/7038 [18:26<27:21,  2.55it/s]
# Iteration:  41% 2851/7038 [18:26<25:50,  2.70it/s]
# Iteration:  41% 2852/7038 [18:26<24:39,  2.83it/s]
# Iteration:  41% 2853/7038 [18:27<23:49,  2.93it/s]
# Iteration:  41% 2854/7038 [18:27<23:12,  3.00it/s]
# Iteration:  41% 2855/7038 [18:27<27:12,  2.56it/s]
# Iteration:  41% 2856/7038 [18:28<25:43,  2.71it/s]
# Iteration:  41% 2857/7038 [18:28<24:27,  2.85it/s]
# Iteration:  41% 2858/7038 [18:28<23:38,  2.95it/s]
# Iteration:  41% 2859/7038 [18:29<23:11,  3.00it/s]
# Iteration:  41% 2860/7038 [18:29<27:13,  2.56it/s]
# Iteration:  41% 2861/7038 [18:29<25:48,  2.70it/s]
# Iteration:  41% 2862/7038 [18:30<24:41,  2.82it/s]
# Iteration:  41% 2863/7038 [18:30<23:52,  2.91it/s]
# Iteration:  41% 2864/7038 [18:30<23:15,  2.99it/s]
# Iteration:  41% 2865/7038 [18:31<27:16,  2.55it/s]
# Iteration:  41% 2866/7038 [18:31<25:42,  2.70it/s]
# Iteration:  41% 2867/7038 [18:32<24:31,  2.83it/s]
# Iteration:  41% 2868/7038 [18:32<23:48,  2.92it/s]
# Iteration:  41% 2869/7038 [18:32<23:03,  3.01it/s]
# Iteration:  41% 2870/7038 [18:33<27:06,  2.56it/s]
# Iteration:  41% 2871/7038 [18:33<25:31,  2.72it/s]
# Iteration:  41% 2872/7038 [18:33<24:23,  2.85it/s]
# Iteration:  41% 2873/7038 [18:34<23:34,  2.95it/s]
# Iteration:  41% 2874/7038 [18:34<23:04,  3.01it/s]
# Iteration:  41% 2875/7038 [18:34<27:11,  2.55it/s]
# Iteration:  41% 2876/7038 [18:35<25:40,  2.70it/s]
# Iteration:  41% 2877/7038 [18:35<24:37,  2.82it/s]
# Iteration:  41% 2878/7038 [18:35<23:58,  2.89it/s]
# Iteration:  41% 2879/7038 [18:36<23:15,  2.98it/s]
# Iteration:  41% 2880/7038 [18:36<27:13,  2.55it/s]
# Iteration:  41% 2881/7038 [18:37<26:11,  2.64it/s]
# Iteration:  41% 2882/7038 [18:37<25:30,  2.71it/s]
# Iteration:  41% 2883/7038 [18:37<24:43,  2.80it/s]
# Iteration:  41% 2884/7038 [18:38<24:00,  2.88it/s]
# Iteration:  41% 2885/7038 [18:38<28:14,  2.45it/s]
# Iteration:  41% 2886/7038 [18:39<26:44,  2.59it/s]
# Iteration:  41% 2887/7038 [18:39<25:21,  2.73it/s]
# Iteration:  41% 2888/7038 [18:39<24:20,  2.84it/s]
# Iteration:  41% 2889/7038 [18:39<23:52,  2.90it/s]
# Iteration:  41% 2890/7038 [18:40<28:04,  2.46it/s]
# Iteration:  41% 2891/7038 [18:40<26:29,  2.61it/s]
# Iteration:  41% 2892/7038 [18:41<25:17,  2.73it/s]
# Iteration:  41% 2893/7038 [18:41<24:31,  2.82it/s]
# Iteration:  41% 2894/7038 [18:41<23:55,  2.89it/s]
# Iteration:  41% 2895/7038 [18:42<27:53,  2.48it/s]
# Iteration:  41% 2896/7038 [18:42<26:24,  2.61it/s]
# Iteration:  41% 2897/7038 [18:43<25:22,  2.72it/s]
# Iteration:  41% 2898/7038 [18:43<24:37,  2.80it/s]
# Iteration:  41% 2899/7038 [18:43<23:57,  2.88it/s]
# Iteration:  41% 2900/7038 [18:44<28:02,  2.46it/s]
# Iteration:  41% 2901/7038 [18:44<26:23,  2.61it/s]
# Iteration:  41% 2902/7038 [18:44<25:10,  2.74it/s]
# Iteration:  41% 2903/7038 [18:45<24:27,  2.82it/s]
# Iteration:  41% 2904/7038 [18:45<23:53,  2.88it/s]
# Iteration:  41% 2905/7038 [18:46<27:54,  2.47it/s]
# Iteration:  41% 2906/7038 [18:46<26:24,  2.61it/s]
# Iteration:  41% 2907/7038 [18:46<25:05,  2.74it/s]
# Iteration:  41% 2908/7038 [18:47<24:20,  2.83it/s]
# Iteration:  41% 2909/7038 [18:47<23:56,  2.87it/s]
# Iteration:  41% 2910/7038 [18:47<28:00,  2.46it/s]
# Iteration:  41% 2911/7038 [18:48<26:35,  2.59it/s]
# Iteration:  41% 2912/7038 [18:48<25:23,  2.71it/s]
# Iteration:  41% 2913/7038 [18:48<24:27,  2.81it/s]
# Iteration:  41% 2914/7038 [18:49<23:49,  2.88it/s]
# Iteration:  41% 2915/7038 [18:49<27:49,  2.47it/s]
# Iteration:  41% 2916/7038 [18:50<26:17,  2.61it/s]
# Iteration:  41% 2917/7038 [18:50<25:01,  2.74it/s]
# Iteration:  41% 2918/7038 [18:50<24:25,  2.81it/s]
# Iteration:  41% 2919/7038 [18:51<23:56,  2.87it/s]
# Iteration:  41% 2920/7038 [18:51<27:51,  2.46it/s]
# Iteration:  42% 2921/7038 [18:52<26:23,  2.60it/s]
# Iteration:  42% 2922/7038 [18:52<25:07,  2.73it/s]
# Iteration:  42% 2923/7038 [18:52<24:22,  2.81it/s]
# Iteration:  42% 2924/7038 [18:53<24:04,  2.85it/s]
# Iteration:  42% 2925/7038 [18:53<28:15,  2.43it/s]
# Iteration:  42% 2926/7038 [18:53<26:27,  2.59it/s]
# Iteration:  42% 2927/7038 [18:54<25:19,  2.71it/s]
# Iteration:  42% 2928/7038 [18:54<24:27,  2.80it/s]
# Iteration:  42% 2929/7038 [18:54<24:05,  2.84it/s]
# Iteration:  42% 2930/7038 [18:55<28:13,  2.43it/s]
# Iteration:  42% 2931/7038 [18:55<26:27,  2.59it/s]
# Iteration:  42% 2932/7038 [18:56<25:13,  2.71it/s]
# Iteration:  42% 2933/7038 [18:56<24:13,  2.82it/s]
# Iteration:  42% 2934/7038 [18:56<23:31,  2.91it/s]
# Iteration:  42% 2935/7038 [18:57<27:35,  2.48it/s]
# Iteration:  42% 2936/7038 [18:57<26:03,  2.62it/s]
# Iteration:  42% 2937/7038 [18:57<25:00,  2.73it/s]
# Iteration:  42% 2938/7038 [18:58<24:10,  2.83it/s]
# Iteration:  42% 2939/7038 [18:58<23:32,  2.90it/s]
# Iteration:  42% 2940/7038 [18:59<27:45,  2.46it/s]
# Iteration:  42% 2941/7038 [18:59<26:12,  2.61it/s]
# Iteration:  42% 2942/7038 [18:59<24:56,  2.74it/s]
# Iteration:  42% 2943/7038 [19:00<24:08,  2.83it/s]
# Iteration:  42% 2944/7038 [19:00<23:37,  2.89it/s]
# Iteration:  42% 2945/7038 [19:01<27:48,  2.45it/s]
# Iteration:  42% 2946/7038 [19:01<26:14,  2.60it/s]
# Iteration:  42% 2947/7038 [19:01<24:55,  2.74it/s]
# Iteration:  42% 2948/7038 [19:01<24:11,  2.82it/s]
# Iteration:  42% 2949/7038 [19:02<23:34,  2.89it/s]
# Iteration:  42% 2950/7038 [19:02<27:36,  2.47it/s]
# Iteration:  42% 2951/7038 [19:03<26:06,  2.61it/s]
# Iteration:  42% 2952/7038 [19:03<24:55,  2.73it/s]
# Iteration:  42% 2953/7038 [19:03<24:19,  2.80it/s]
# Iteration:  42% 2954/7038 [19:04<23:50,  2.86it/s]
# Iteration:  42% 2955/7038 [19:04<27:38,  2.46it/s]
# Iteration:  42% 2956/7038 [19:05<25:50,  2.63it/s]
# Iteration:  42% 2957/7038 [19:05<24:22,  2.79it/s]
# Iteration:  42% 2958/7038 [19:05<23:22,  2.91it/s]
# Iteration:  42% 2959/7038 [19:05<22:43,  2.99it/s]
# Iteration:  42% 2960/7038 [19:06<26:54,  2.53it/s]
# Iteration:  42% 2961/7038 [19:06<25:28,  2.67it/s]
# Iteration:  42% 2962/7038 [19:07<24:10,  2.81it/s]
# Iteration:  42% 2963/7038 [19:07<23:23,  2.90it/s]
# Iteration:  42% 2964/7038 [19:07<22:52,  2.97it/s]06/27/2020 14:34:18 - INFO - transformers.trainer -   {'loss': 2.966938254714012, 'learning_rate': 1.4463397299218195e-05, 'epoch': 1.42128445581131, 'step': 2000}
# 06/27/2020 14:34:18 - WARNING - transformers.training_args -   Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.
# 06/27/2020 14:34:18 - INFO - transformers.trainer -   ***** Running Evaluation *****
# 06/27/2020 14:34:18 - INFO - transformers.trainer -     Num examples = 0
# 06/27/2020 14:34:18 - INFO - transformers.trainer -     Batch size = 2
#
#
# Evaluation: 0it [00:00, ?it/s]
# 06/27/2020 14:34:18 - INFO - transformers.trainer -   {'epoch': 1.42128445581131, 'step': 2000}
# 06/27/2020 14:34:18 - INFO - transformers.trainer -   Saving model checkpoint to /content/drive/My Drive/finetuned_models/presidential_speeches/checkpoint-2000
# 06/27/2020 14:34:18 - INFO - transformers.configuration_utils -   Configuration saved in /content/drive/My Drive/finetuned_models/presidential_speeches/checkpoint-2000/config.json
# 06/27/2020 14:34:25 - INFO - transformers.modeling_utils -   Model weights saved in /content/drive/My Drive/finetuned_models/presidential_speeches/checkpoint-2000/pytorch_model.bin
#
# Iteration:  42% 2965/7038 [20:27<27:19:14, 24.15s/it]
# Iteration:  42% 2966/7038 [20:27<19:14:06, 17.01s/it]
# Iteration:  42% 2967/7038 [20:28<13:34:03, 12.00s/it]
# Iteration:  42% 2968/7038 [20:28<9:36:00,  8.49s/it]
# Iteration:  42% 2969/7038 [20:28<6:49:32,  6.04s/it]
# Iteration:  42% 2970/7038 [20:29<4:57:18,  4.39s/it]
# Iteration:  42% 2971/7038 [20:29<3:34:29,  3.16s/it]
# Iteration:  42% 2972/7038 [20:29<2:36:24,  2.31s/it]
# Iteration:  42% 2973/7038 [20:30<1:55:44,  1.71s/it]
# Iteration:  42% 2974/7038 [20:30<1:27:19,  1.29s/it]
# Iteration:  42% 2975/7038 [20:31<1:11:44,  1.06s/it]
# Iteration:  42% 2976/7038 [20:31<56:36,  1.20it/s]
# Iteration:  42% 2977/7038 [20:31<45:53,  1.47it/s]
# Iteration:  42% 2978/7038 [20:31<38:22,  1.76it/s]
# Iteration:  42% 2979/7038 [20:32<33:13,  2.04it/s]
# Iteration:  42% 2980/7038 [20:32<33:52,  2.00it/s]
# Iteration:  42% 2981/7038 [20:33<30:04,  2.25it/s]
# Iteration:  42% 2982/7038 [20:33<27:18,  2.48it/s]
# Iteration:  42% 2983/7038 [20:33<25:28,  2.65it/s]
# Iteration:  42% 2984/7038 [20:34<24:08,  2.80it/s]
# Iteration:  42% 2985/7038 [20:34<27:34,  2.45it/s]
# Iteration:  42% 2986/7038 [20:34<25:42,  2.63it/s]
# Iteration:  42% 2987/7038 [20:35<24:26,  2.76it/s]
# Iteration:  42% 2988/7038 [20:35<23:22,  2.89it/s]
# Iteration:  42% 2989/7038 [20:35<22:41,  2.97it/s]
# Iteration:  42% 2990/7038 [20:36<26:30,  2.55it/s]
# Iteration:  42% 2991/7038 [20:36<24:56,  2.70it/s]
# Iteration:  43% 2992/7038 [20:37<23:55,  2.82it/s]
# Iteration:  43% 2993/7038 [20:37<23:06,  2.92it/s]
# Iteration:  43% 2994/7038 [20:37<22:28,  3.00it/s]
# Iteration:  43% 2995/7038 [20:38<26:29,  2.54it/s]
# Iteration:  43% 2996/7038 [20:38<24:59,  2.70it/s]
# Iteration:  43% 2997/7038 [20:38<23:44,  2.84it/s]
# Iteration:  43% 2998/7038 [20:39<22:57,  2.93it/s]
# Iteration:  43% 2999/7038 [20:39<22:25,  3.00it/s]
# Iteration:  43% 3000/7038 [20:39<26:19,  2.56it/s]
# ...
# Iteration:  96% 6755/7038 [44:34<01:50,  2.56it/s]
# Iteration:  96% 6756/7038 [44:35<01:44,  2.70it/s]
# Iteration:  96% 6757/7038 [44:35<01:38,  2.84it/s]
# Iteration:  96% 6758/7038 [44:35<01:35,  2.94it/s]
# Iteration:  96% 6759/7038 [44:36<01:32,  3.01it/s]
# Iteration:  96% 6760/7038 [44:36<01:49,  2.55it/s]
# Iteration:  96% 6761/7038 [44:37<01:42,  2.71it/s]
# Iteration:  96% 6762/7038 [44:37<01:37,  2.83it/s]
# Iteration:  96% 6763/7038 [44:37<01:34,  2.91it/s]
# Iteration:  96% 6764/7038 [44:37<01:32,  2.97it/s]
# Iteration:  96% 6765/7038 [44:38<01:47,  2.54it/s]
# Iteration:  96% 6766/7038 [44:38<01:40,  2.70it/s]
# Iteration:  96% 6767/7038 [44:39<01:35,  2.84it/s]
# Iteration:  96% 6768/7038 [44:39<01:31,  2.94it/s]
# Iteration:  96% 6769/7038 [44:39<01:29,  2.99it/s]
# Iteration:  96% 6770/7038 [44:40<01:44,  2.55it/s]
# Iteration:  96% 6771/7038 [44:40<01:38,  2.71it/s]
# Iteration:  96% 6772/7038 [44:40<01:33,  2.84it/s]
# Iteration:  96% 6773/7038 [44:41<01:30,  2.94it/s]
# Iteration:  96% 6774/7038 [44:41<01:27,  3.03it/s]
# Iteration:  96% 6775/7038 [44:42<01:42,  2.56it/s]
# Iteration:  96% 6776/7038 [44:42<01:37,  2.70it/s]
# Iteration:  96% 6777/7038 [44:42<01:32,  2.83it/s]
# Iteration:  96% 6778/7038 [44:43<01:28,  2.95it/s]
# Iteration:  96% 6779/7038 [44:43<01:26,  3.01it/s]
# Iteration:  96% 6780/7038 [44:43<01:41,  2.55it/s]
# Iteration:  96% 6781/7038 [44:44<01:34,  2.71it/s]
# Iteration:  96% 6782/7038 [44:44<01:30,  2.84it/s]
# Iteration:  96% 6783/7038 [44:44<01:27,  2.92it/s]
# Iteration:  96% 6784/7038 [44:45<01:24,  3.00it/s]
# Iteration:  96% 6785/7038 [44:45<01:39,  2.56it/s]
# Iteration:  96% 6786/7038 [44:45<01:32,  2.71it/s]
# Iteration:  96% 6787/7038 [44:46<01:27,  2.85it/s]
# Iteration:  96% 6788/7038 [44:46<01:24,  2.96it/s]
# Iteration:  96% 6789/7038 [44:46<01:22,  3.01it/s]
# Iteration:  96% 6790/7038 [44:47<01:37,  2.55it/s]
# Iteration:  96% 6791/7038 [44:47<01:31,  2.71it/s]
# Iteration:  97% 6792/7038 [44:48<01:26,  2.85it/s]
# Iteration:  97% 6793/7038 [44:48<01:23,  2.94it/s]
# Iteration:  97% 6794/7038 [44:48<01:20,  3.03it/s]
# Iteration:  97% 6795/7038 [44:49<01:34,  2.57it/s]
# Iteration:  97% 6796/7038 [44:49<01:28,  2.73it/s]
# Iteration:  97% 6797/7038 [44:49<01:24,  2.85it/s]
# Iteration:  97% 6798/7038 [44:50<01:21,  2.93it/s]
# Iteration:  97% 6799/7038 [44:50<01:19,  3.01it/s]
# Iteration:  97% 6800/7038 [44:50<01:32,  2.56it/s]
# Iteration:  97% 6801/7038 [44:51<01:27,  2.71it/s]
# Iteration:  97% 6802/7038 [44:51<01:23,  2.84it/s]
# Iteration:  97% 6803/7038 [44:51<01:20,  2.93it/s]
# Iteration:  97% 6804/7038 [44:52<01:18,  2.98it/s]
# Iteration:  97% 6805/7038 [44:52<01:32,  2.53it/s]
# Iteration:  97% 6806/7038 [44:53<01:26,  2.68it/s]
# Iteration:  97% 6807/7038 [44:53<01:22,  2.81it/s]
# Iteration:  97% 6808/7038 [44:53<01:18,  2.92it/s]
# Iteration:  97% 6809/7038 [44:54<01:16,  3.00it/s]
# Iteration:  97% 6810/7038 [44:54<01:29,  2.55it/s]
# Iteration:  97% 6811/7038 [44:54<01:24,  2.69it/s]
# Iteration:  97% 6812/7038 [44:55<01:20,  2.82it/s]
# Iteration:  97% 6813/7038 [44:55<01:16,  2.93it/s]
# Iteration:  97% 6814/7038 [44:55<01:14,  3.01it/s]
# Iteration:  97% 6815/7038 [44:56<01:27,  2.55it/s]
# Iteration:  97% 6816/7038 [44:56<01:21,  2.71it/s]
# Iteration:  97% 6817/7038 [44:56<01:18,  2.83it/s]
# Iteration:  97% 6818/7038 [44:57<01:15,  2.93it/s]
# Iteration:  97% 6819/7038 [44:57<01:12,  3.01it/s]
# Iteration:  97% 6820/7038 [44:58<01:25,  2.55it/s]
# Iteration:  97% 6821/7038 [44:58<01:20,  2.69it/s]
# Iteration:  97% 6822/7038 [44:58<01:16,  2.83it/s]
# Iteration:  97% 6823/7038 [44:59<01:13,  2.92it/s]
# Iteration:  97% 6824/7038 [44:59<01:11,  2.98it/s]
# Iteration:  97% 6825/7038 [44:59<01:24,  2.53it/s]
# Iteration:  97% 6826/7038 [45:00<01:19,  2.68it/s]
# Iteration:  97% 6827/7038 [45:00<01:14,  2.82it/s]
# Iteration:  97% 6828/7038 [45:00<01:12,  2.91it/s]
# Iteration:  97% 6829/7038 [45:01<01:09,  2.99it/s]
# Iteration:  97% 6830/7038 [45:01<01:21,  2.54it/s]
# Iteration:  97% 6831/7038 [45:02<01:16,  2.70it/s]
# Iteration:  97% 6832/7038 [45:02<01:12,  2.83it/s]
# Iteration:  97% 6833/7038 [45:02<01:09,  2.94it/s]
# Iteration:  97% 6834/7038 [45:03<01:07,  3.02it/s]
# Iteration:  97% 6835/7038 [45:03<01:19,  2.56it/s]
# Iteration:  97% 6836/7038 [45:03<01:14,  2.72it/s]
# Iteration:  97% 6837/7038 [45:04<01:10,  2.84it/s]
# Iteration:  97% 6838/7038 [45:04<01:07,  2.94it/s]
# Iteration:  97% 6839/7038 [45:04<01:05,  3.03it/s]
# Iteration:  97% 6840/7038 [45:05<01:17,  2.56it/s]
# Iteration:  97% 6841/7038 [45:05<01:12,  2.71it/s]
# Iteration:  97% 6842/7038 [45:05<01:08,  2.84it/s]
# Iteration:  97% 6843/7038 [45:06<01:06,  2.92it/s]
# Iteration:  97% 6844/7038 [45:06<01:04,  3.01it/s]
# Iteration:  97% 6845/7038 [45:07<01:15,  2.56it/s]
# Iteration:  97% 6846/7038 [45:07<01:10,  2.72it/s]
# Iteration:  97% 6847/7038 [45:07<01:06,  2.85it/s]
# Iteration:  97% 6848/7038 [45:08<01:04,  2.95it/s]
# Iteration:  97% 6849/7038 [45:08<01:02,  3.01it/s]
# Iteration:  97% 6850/7038 [45:08<01:13,  2.56it/s]
# Iteration:  97% 6851/7038 [45:09<01:09,  2.70it/s]
# Iteration:  97% 6852/7038 [45:09<01:05,  2.82it/s]
# Iteration:  97% 6853/7038 [45:09<01:03,  2.92it/s]
# Iteration:  97% 6854/7038 [45:10<01:01,  2.98it/s]
# Iteration:  97% 6855/7038 [45:10<01:12,  2.54it/s]
# Iteration:  97% 6856/7038 [45:11<01:07,  2.69it/s]
# Iteration:  97% 6857/7038 [45:11<01:03,  2.83it/s]
# Iteration:  97% 6858/7038 [45:11<01:01,  2.94it/s]
# Iteration:  97% 6859/7038 [45:11<00:59,  3.01it/s]
# Iteration:  97% 6860/7038 [45:12<01:09,  2.56it/s]
# Iteration:  97% 6861/7038 [45:12<01:05,  2.71it/s]
# Iteration:  97% 6862/7038 [45:13<01:01,  2.85it/s]
# Iteration:  98% 6863/7038 [45:13<00:59,  2.95it/s]
# Iteration:  98% 6864/7038 [45:13<00:57,  3.02it/s]
# Iteration:  98% 6865/7038 [45:14<01:07,  2.57it/s]
# Iteration:  98% 6866/7038 [45:14<01:03,  2.72it/s]
# Iteration:  98% 6867/7038 [45:14<00:59,  2.85it/s]
# Iteration:  98% 6868/7038 [45:15<00:57,  2.93it/s]
# Iteration:  98% 6869/7038 [45:15<00:56,  2.99it/s]
# Iteration:  98% 6870/7038 [45:16<01:05,  2.55it/s]
# Iteration:  98% 6871/7038 [45:16<01:01,  2.71it/s]
# Iteration:  98% 6872/7038 [45:16<00:58,  2.83it/s]
# Iteration:  98% 6873/7038 [45:16<00:56,  2.93it/s]
# Iteration:  98% 6874/7038 [45:17<00:54,  3.01it/s]
# Iteration:  98% 6875/7038 [45:17<01:03,  2.56it/s]
# Iteration:  98% 6876/7038 [45:18<00:59,  2.72it/s]
# Iteration:  98% 6877/7038 [45:18<00:56,  2.85it/s]
# Iteration:  98% 6878/7038 [45:18<00:54,  2.95it/s]
# Iteration:  98% 6879/7038 [45:19<00:52,  3.04it/s]
# Iteration:  98% 6880/7038 [45:19<01:01,  2.56it/s]
# Iteration:  98% 6881/7038 [45:19<00:58,  2.70it/s]
# Iteration:  98% 6882/7038 [45:20<00:55,  2.83it/s]
# Iteration:  98% 6883/7038 [45:20<00:52,  2.94it/s]
# Iteration:  98% 6884/7038 [45:20<00:51,  3.01it/s]
# Iteration:  98% 6885/7038 [45:21<00:59,  2.55it/s]
# Iteration:  98% 6886/7038 [45:21<00:56,  2.69it/s]
# Iteration:  98% 6887/7038 [45:22<00:53,  2.81it/s]
# Iteration:  98% 6888/7038 [45:22<00:51,  2.92it/s]
# Iteration:  98% 6889/7038 [45:22<00:50,  2.97it/s]
# Iteration:  98% 6890/7038 [45:23<00:58,  2.55it/s]
# Iteration:  98% 6891/7038 [45:23<00:54,  2.70it/s]
# Iteration:  98% 6892/7038 [45:23<00:51,  2.83it/s]
# Iteration:  98% 6893/7038 [45:24<00:49,  2.93it/s]
# Iteration:  98% 6894/7038 [45:24<00:47,  3.00it/s]
# Iteration:  98% 6895/7038 [45:24<00:55,  2.56it/s]
# Iteration:  98% 6896/7038 [45:25<00:52,  2.70it/s]
# Iteration:  98% 6897/7038 [45:25<00:49,  2.82it/s]
# Iteration:  98% 6898/7038 [45:25<00:47,  2.94it/s]
# Iteration:  98% 6899/7038 [45:26<00:46,  3.00it/s]
# Iteration:  98% 6900/7038 [45:26<00:53,  2.56it/s]
# Iteration:  98% 6901/7038 [45:27<00:50,  2.69it/s]
# Iteration:  98% 6902/7038 [45:27<00:48,  2.79it/s]
# Iteration:  98% 6903/7038 [45:27<00:46,  2.90it/s]
# Iteration:  98% 6904/7038 [45:28<00:44,  2.98it/s]
# Iteration:  98% 6905/7038 [45:28<00:52,  2.54it/s]
# Iteration:  98% 6906/7038 [45:28<00:48,  2.69it/s]
# Iteration:  98% 6907/7038 [45:29<00:46,  2.82it/s]
# Iteration:  98% 6908/7038 [45:29<00:44,  2.93it/s]
# Iteration:  98% 6909/7038 [45:29<00:43,  2.99it/s]
# Iteration:  98% 6910/7038 [45:30<00:50,  2.55it/s]
# Iteration:  98% 6911/7038 [45:30<00:47,  2.70it/s]
# Iteration:  98% 6912/7038 [45:30<00:44,  2.83it/s]
# Iteration:  98% 6913/7038 [45:31<00:42,  2.94it/s]
# Iteration:  98% 6914/7038 [45:31<00:41,  3.01it/s]
# Iteration:  98% 6915/7038 [45:32<00:48,  2.54it/s]
# Iteration:  98% 6916/7038 [45:32<00:45,  2.70it/s]
# Iteration:  98% 6917/7038 [45:32<00:42,  2.82it/s]
# Iteration:  98% 6918/7038 [45:33<00:41,  2.90it/s]
# Iteration:  98% 6919/7038 [45:33<00:40,  2.97it/s]
# Iteration:  98% 6920/7038 [45:33<00:46,  2.54it/s]
# Iteration:  98% 6921/7038 [45:34<00:43,  2.70it/s]
# Iteration:  98% 6922/7038 [45:34<00:41,  2.81it/s]
# Iteration:  98% 6923/7038 [45:34<00:39,  2.91it/s]
# Iteration:  98% 6924/7038 [45:35<00:37,  3.00it/s]
# Iteration:  98% 6925/7038 [45:35<00:44,  2.55it/s]
# Iteration:  98% 6926/7038 [45:36<00:41,  2.70it/s]
# Iteration:  98% 6927/7038 [45:36<00:39,  2.84it/s]
# Iteration:  98% 6928/7038 [45:36<00:37,  2.94it/s]
# Iteration:  98% 6929/7038 [45:37<00:36,  2.98it/s]
# Iteration:  98% 6930/7038 [45:37<00:42,  2.54it/s]
# Iteration:  98% 6931/7038 [45:37<00:39,  2.69it/s]
# Iteration:  98% 6932/7038 [45:38<00:37,  2.82it/s]
# Iteration:  99% 6933/7038 [45:38<00:35,  2.94it/s]
# Iteration:  99% 6934/7038 [45:38<00:34,  3.00it/s]
# Iteration:  99% 6935/7038 [45:39<00:40,  2.56it/s]
# Iteration:  99% 6936/7038 [45:39<00:37,  2.71it/s]
# Iteration:  99% 6937/7038 [45:39<00:35,  2.84it/s]
# Iteration:  99% 6938/7038 [45:40<00:33,  2.95it/s]
# Iteration:  99% 6939/7038 [45:40<00:32,  3.02it/s]
# Iteration:  99% 6940/7038 [45:41<00:38,  2.56it/s]
# Iteration:  99% 6941/7038 [45:41<00:35,  2.71it/s]
# Iteration:  99% 6942/7038 [45:41<00:33,  2.83it/s]
# Iteration:  99% 6943/7038 [45:42<00:32,  2.93it/s]
# Iteration:  99% 6944/7038 [45:42<00:31,  3.01it/s]
# Iteration:  99% 6945/7038 [45:42<00:36,  2.56it/s]
# Iteration:  99% 6946/7038 [45:43<00:33,  2.71it/s]
# Iteration:  99% 6947/7038 [45:43<00:32,  2.84it/s]
# Iteration:  99% 6948/7038 [45:43<00:30,  2.91it/s]
# Iteration:  99% 6949/7038 [45:44<00:29,  2.98it/s]
# Iteration:  99% 6950/7038 [45:44<00:34,  2.54it/s]
# Iteration:  99% 6951/7038 [45:45<00:32,  2.71it/s]
# Iteration:  99% 6952/7038 [45:45<00:30,  2.84it/s]
# Iteration:  99% 6953/7038 [45:45<00:28,  2.93it/s]
# Iteration:  99% 6954/7038 [45:45<00:27,  3.01it/s]
# Iteration:  99% 6955/7038 [45:46<00:32,  2.56it/s]
# Iteration:  99% 6956/7038 [45:46<00:30,  2.72it/s]
# Iteration:  99% 6957/7038 [45:47<00:28,  2.85it/s]
# Iteration:  99% 6958/7038 [45:47<00:27,  2.94it/s]
# Iteration:  99% 6959/7038 [45:47<00:26,  3.02it/s]
# Iteration:  99% 6960/7038 [45:48<00:30,  2.56it/s]
# Iteration:  99% 6961/7038 [45:48<00:28,  2.71it/s]
# Iteration:  99% 6962/7038 [45:48<00:26,  2.85it/s]
# Iteration:  99% 6963/7038 [45:49<00:25,  2.94it/s]
# Iteration:  99% 6964/7038 [45:49<00:24,  3.03it/s]
# Iteration:  99% 6965/7038 [45:50<00:28,  2.56it/s]
# Iteration:  99% 6966/7038 [45:50<00:26,  2.72it/s]
# Iteration:  99% 6967/7038 [45:50<00:24,  2.86it/s]
# Iteration:  99% 6968/7038 [45:50<00:23,  2.94it/s]
# Iteration:  99% 6969/7038 [45:51<00:22,  3.02it/s]
# Iteration:  99% 6970/7038 [45:51<00:26,  2.57it/s]
# Iteration:  99% 6971/7038 [45:52<00:24,  2.72it/s]
# Iteration:  99% 6972/7038 [45:52<00:23,  2.85it/s]
# Iteration:  99% 6973/7038 [45:52<00:22,  2.94it/s]
# Iteration:  99% 6974/7038 [45:53<00:21,  3.03it/s]
# Iteration:  99% 6975/7038 [45:53<00:24,  2.56it/s]
# Iteration:  99% 6976/7038 [45:53<00:22,  2.70it/s]
# Iteration:  99% 6977/7038 [45:54<00:21,  2.81it/s]
# Iteration:  99% 6978/7038 [45:54<00:20,  2.91it/s]
# Iteration:  99% 6979/7038 [45:54<00:19,  3.00it/s]
# Iteration:  99% 6980/7038 [45:55<00:22,  2.54it/s]
# Iteration:  99% 6981/7038 [45:55<00:21,  2.69it/s]
# Iteration:  99% 6982/7038 [45:56<00:19,  2.81it/s]
# Iteration:  99% 6983/7038 [45:56<00:18,  2.92it/s]
# Iteration:  99% 6984/7038 [45:56<00:18,  3.00it/s]
# Iteration:  99% 6985/7038 [45:57<00:20,  2.56it/s]
# Iteration:  99% 6986/7038 [45:57<00:19,  2.71it/s]
# Iteration:  99% 6987/7038 [45:57<00:17,  2.85it/s]
# Iteration:  99% 6988/7038 [45:58<00:16,  2.95it/s]
# Iteration:  99% 6989/7038 [45:58<00:16,  3.02it/s]
# Iteration:  99% 6990/7038 [45:58<00:18,  2.56it/s]
# Iteration:  99% 6991/7038 [45:59<00:17,  2.70it/s]
# Iteration:  99% 6992/7038 [45:59<00:16,  2.84it/s]
# Iteration:  99% 6993/7038 [45:59<00:15,  2.92it/s]
# Iteration:  99% 6994/7038 [46:00<00:14,  2.97it/s]
# Iteration:  99% 6995/7038 [46:00<00:16,  2.53it/s]
# Iteration:  99% 6996/7038 [46:01<00:15,  2.69it/s]
# Iteration:  99% 6997/7038 [46:01<00:14,  2.81it/s]
# Iteration:  99% 6998/7038 [46:01<00:13,  2.92it/s]
# Iteration:  99% 6999/7038 [46:02<00:12,  3.01it/s]
# Iteration:  99% 7000/7038 [46:02<00:14,  2.55it/s]
# Iteration:  99% 7001/7038 [46:02<00:13,  2.71it/s]
# Iteration:  99% 7002/7038 [46:03<00:12,  2.83it/s]
# Iteration: 100% 7003/7038 [46:03<00:11,  2.93it/s]
# Iteration: 100% 7004/7038 [46:03<00:11,  3.00it/s]
# Iteration: 100% 7005/7038 [46:04<00:12,  2.55it/s]
# Iteration: 100% 7006/7038 [46:04<00:11,  2.71it/s]
# Iteration: 100% 7007/7038 [46:04<00:10,  2.85it/s]
# Iteration: 100% 7008/7038 [46:05<00:10,  2.94it/s]
# Iteration: 100% 7009/7038 [46:05<00:09,  3.03it/s]
# Iteration: 100% 7010/7038 [46:06<00:10,  2.57it/s]
# Iteration: 100% 7011/7038 [46:06<00:09,  2.72it/s]
# Iteration: 100% 7012/7038 [46:06<00:09,  2.85it/s]
# Iteration: 100% 7013/7038 [46:07<00:08,  2.96it/s]
# Iteration: 100% 7014/7038 [46:07<00:07,  3.02it/s]
# Iteration: 100% 7015/7038 [46:07<00:09,  2.55it/s]
# Iteration: 100% 7016/7038 [46:08<00:08,  2.71it/s]
# Iteration: 100% 7017/7038 [46:08<00:07,  2.84it/s]
# Iteration: 100% 7018/7038 [46:08<00:06,  2.95it/s]
# Iteration: 100% 7019/7038 [46:09<00:06,  3.02it/s]
# Iteration: 100% 7020/7038 [46:09<00:07,  2.54it/s]
# Iteration: 100% 7021/7038 [46:10<00:06,  2.70it/s]
# Iteration: 100% 7022/7038 [46:10<00:05,  2.83it/s]
# Iteration: 100% 7023/7038 [46:10<00:05,  2.94it/s]
# Iteration: 100% 7024/7038 [46:10<00:04,  3.02it/s]
# Iteration: 100% 7025/7038 [46:11<00:05,  2.57it/s]
# Iteration: 100% 7026/7038 [46:11<00:04,  2.68it/s]
# Iteration: 100% 7027/7038 [46:12<00:03,  2.81it/s]
# Iteration: 100% 7028/7038 [46:12<00:03,  2.92it/s]
# Iteration: 100% 7029/7038 [46:12<00:02,  3.01it/s]
# Iteration: 100% 7030/7038 [46:13<00:03,  2.56it/s]
# Iteration: 100% 7031/7038 [46:13<00:02,  2.71it/s]
# Iteration: 100% 7032/7038 [46:13<00:02,  2.84it/s]
# Iteration: 100% 7033/7038 [46:14<00:01,  2.94it/s]
# Iteration: 100% 7034/7038 [46:14<00:01,  3.01it/s]
# Iteration: 100% 7035/7038 [46:15<00:01,  2.55it/s]
# Iteration: 100% 7036/7038 [46:15<00:00,  2.71it/s]
# Iteration: 100% 7037/7038 [46:15<00:00,  2.85it/s]
# Iteration: 100% 7038/7038 [46:15<00:00,  2.54it/s]
# Epoch: 100% 2/2 [1:30:56<00:00, 2728.50s/it]
# 06/27/2020 15:01:26 - INFO - transformers.trainer -
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# 06/27/2020 15:01:26 - INFO - transformers.trainer -   Saving model checkpoint to /content/drive/My Drive/finetuned_models/presidential_speeches
# 06/27/2020 15:01:26 - INFO - transformers.configuration_utils -   Configuration saved in /content/drive/My Drive/finetuned_models/presidential_speeches/config.json
# 06/27/2020 15:01:33 - INFO - transformers.modeling_utils -   Model weights saved in /content/drive/My Drive/finetuned_models/presidential_speeches/pytorch_model.bin
# 06/27/2020 15:01:36 - INFO - __main__ -   *** Evaluate ***
# 06/27/2020 15:01:36 - WARNING - transformers.training_args -   Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.
# 06/27/2020 15:01:36 - INFO - transformers.trainer -   ***** Running Evaluation *****
# 06/27/2020 15:01:36 - INFO - transformers.trainer -     Num examples = 0
# 06/27/2020 15:01:36 - INFO - transformers.trainer -     Batch size = 2
# Evaluation: 0it [00:00, ?it/s]
# 06/27/2020 15:01:36 - INFO - transformers.trainer -   {'epoch': 1.9995737425404945, 'step': 2814}
# Traceback (most recent call last):
#   File "run_language_modeling.py", line 281, in <module>
#     main()
#   File "run_language_modeling.py", line 259, in main
#     perplexity = math.exp(eval_output["eval_loss"])
# KeyError: 'eval_loss'

# %% [markdown]
# ### Compute perplexity of a dataset.
# This section shows how to compute perplexity of a dataset according to either the pre-trained or your fine-tuned language model. While this is possible to do by calling `run_language_modeling.py` on the command-line as above, we'll instead call the Python functions directly.

# %% [markdown]
# #### Look at what checkpoints are available
# Run `ls` to look at what checkpoints saved been saved. You'll want to set `CHECKPOINT_PATH` below to one of these in order to evaluate the model weights saved in that checkpoint.

# %%
# !ls '/content/drive/My Drive/finetuned_models/presidential_speeches'
# Out:
# checkpoint-1000  checkpoint-500     special_tokens_map.json
# checkpoint-1500  config.json	    tokenizer_config.json
# checkpoint-2000  merges.txt	    training_args.bin
# checkpoint-2500  pytorch_model.bin  vocab.json

# %% [markdown]
# #### Helper functions

# %%
def load_model(args):
  """Creates a model and loads in weights for it."""
  config = AutoConfig.from_pretrained(args.model_name_or_path, cache_dir=None)

  model = AutoModelWithLMHead.from_pretrained(
      args.model_name_or_path,
      from_tf=bool(".ckpt" in args.model_name_or_path),
      config=config,
      cache_dir=None
  )
  
  model.to(args.device)
  return model

def set_seed(seed):
  """Set the random seed."""
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  if args.n_gpu > 0:
    torch.cuda.manual_seed_all(args.seed)

def do_perplexity_eval(args, model, data_file_path):
  """Computes the perplexity of the text in data_file_path according to the provided model."""
  set_seed(args.seed)

  args.eval_data_file=data_file_path

  tokenizer = AutoTokenizer.from_pretrained(args.model_name_or_path, cache_dir=None)

  args.block_size = min(args.block_size, tokenizer.max_len)

  result = run_language_modeling.evaluate(args, model, tokenizer, prefix="")
  return result

# %% [markdown]
# #### Compute it.

# %%
# Set this to the checkpoint you want to evalute, or to "gpt2-medium" to
# evaluate the pre-trained model without finetuning.
# CHECKPOINT_PATH = '/content/drive/My Drive/finetuned_models/presidential_speeches/checkpoint-1500'
import torch
import run_language_modeling
import run_generation
CHECKPOINT_PATH = "gpt2-medium"

# Set this to the list of text files you want to evaluate the perplexity of.
DATA_PATHS = ["/content/presidential_speeches_valid.txt",
              "/content/presidential_speeches_test.txt"]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
print("Running on device: ", device)

args = collections.defaultdict(
  model_name_or_path=CHECKPOINT_PATH,
  output_dir=CHECKPOINT_PATH,
  block_size = 128,
  local_rank=-1,
  eval_batch_size=2,
  per_gpu_eval_batch_size=2,
  n_gpu=n_gpu,
  mlm=False,
  device=device,
  line_by_line=False,
  overwrite_cache=None,
  model_type='gpt2',
  seed=42,
)
args = DictToObj(args)

model = load_model(args)

for data_path in DATA_PATHS:
  eval_results = do_perplexity_eval(args, model, data_path)
  perplexity = eval_results['perplexity']
  print('{} is the perplexity of {} according to {}'.format(
      perplexity, data_path, CHECKPOINT_PATH))
# Out:
# Running on device:  cuda
# 06/27/2020 15:10:17 - INFO - transformers.configuration_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-medium-config.json from cache at /root/.cache/torch/transformers/98aa65385e18b0efd17acd8bf64dcdf21406bb0c99c801c2d3c9f6bfd1f48f29.250d6dc755ccb17d19c7c1a7677636683aa35f0f6cb5461b3c0587bc091551a0
# 06/27/2020 15:10:17 - INFO - transformers.configuration_utils -   Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 1024,
#   "n_head": 16,
#   "n_layer": 24,
#   "n_positions": 1024,
#   "n_special": 0,
#   "predict_special_tokens": true,
#   "resid_pdrop": 0.1,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "vocab_size": 50257
# }
#
# /usr/local/lib/python3.6/dist-packages/transformers/modeling_auto.py:791: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   FutureWarning,
# 06/27/2020 15:10:17 - INFO - transformers.modeling_utils -   loading weights file https://cdn.huggingface.co/gpt2-medium-pytorch_model.bin from cache at /root/.cache/torch/transformers/64652c50e84ddabb9bad81a37ff82624ab70053f402f8d9a58c0e90fb8289fb6.8769029be4f66a5ae1055eefdd1d11621b901d510654266b8681719fff492d6e
# 06/27/2020 15:11:10 - INFO - transformers.modeling_utils -   All model checkpoint weights were used when initializing GPT2LMHeadModel.
#
# 06/27/2020 15:11:10 - WARNING - transformers.modeling_utils -   Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2-medium and are newly initialized: ['h.0.attn.masked_bias', 'h.1.attn.masked_bias', 'h.2.attn.masked_bias', 'h.3.attn.masked_bias', 'h.4.attn.masked_bias', 'h.5.attn.masked_bias', 'h.6.attn.masked_bias', 'h.7.attn.masked_bias', 'h.8.attn.masked_bias', 'h.9.attn.masked_bias', 'h.10.attn.masked_bias', 'h.11.attn.masked_bias', 'h.12.attn.masked_bias', 'h.13.attn.masked_bias', 'h.14.attn.masked_bias', 'h.15.attn.masked_bias', 'h.16.attn.masked_bias', 'h.17.attn.masked_bias', 'h.18.attn.masked_bias', 'h.19.attn.masked_bias', 'h.20.attn.masked_bias', 'h.21.attn.masked_bias', 'h.22.attn.masked_bias', 'h.23.attn.masked_bias', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 06/27/2020 15:11:11 - INFO - transformers.configuration_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-medium-config.json from cache at /root/.cache/torch/transformers/98aa65385e18b0efd17acd8bf64dcdf21406bb0c99c801c2d3c9f6bfd1f48f29.250d6dc755ccb17d19c7c1a7677636683aa35f0f6cb5461b3c0587bc091551a0
# 06/27/2020 15:11:11 - INFO - transformers.configuration_utils -   Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 1024,
#   "n_head": 16,
#   "n_layer": 24,
#   "n_positions": 1024,
#   "n_special": 0,
#   "predict_special_tokens": true,
#   "resid_pdrop": 0.1,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "vocab_size": 50257
# }
#
# 06/27/2020 15:11:12 - INFO - transformers.tokenization_utils_base -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-medium-vocab.json from cache at /root/.cache/torch/transformers/f20f05d3ae37c4e3cd56764d48e566ea5adeba153dcee6eb82a18822c9c731ec.1512018be4ba4e8726e41b9145129dc30651ea4fec86aa61f4b9f40bf94eac71
# 06/27/2020 15:11:12 - INFO - transformers.tokenization_utils_base -   loading file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-medium-merges.txt from cache at /root/.cache/torch/transformers/6d882670c55563617571fe0c97df88626fb5033927b40fc18a8acf98dafd4946.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-5c28ee1c154c> in <module>()
#      35
#      36 for data_path in DATA_PATHS:
# ---> 37   eval_results = do_perplexity_eval(args, model, data_path)
#      38   perplexity = eval_results['perplexity']
#      39   print('{} is the perplexity of {} according to {}'.format(
#
# <ipython-input-18-5969f7fdacd7> in do_perplexity_eval(args, model, data_file_path)
#      31   args.block_size = min(args.block_size, tokenizer.max_len)
#      32
# ---> 33   result = run_language_modeling.evaluate(args, model, tokenizer, prefix="")
#      34   return result
#
# AttributeError: module 'run_language_modeling' has no attribute 'evaluate'

# %% [markdown]
# ### Generate samples
# The following code generates text samples that are are continuations of a provided prompt.

# %%
def generate_samples(args, model, prompt_text):
  """Generating sampling for the provided prompt using the provided model."""
  set_seed(args.seed)

  tokenizer = AutoTokenizer.from_pretrained(args.model_name_or_path, cache_dir=None)

  requires_preprocessing = args.model_type in run_generation.PREPROCESSING_FUNCTIONS.keys()
  encoded_prompt = tokenizer.encode(prompt_text, add_special_tokens=False, return_tensors="pt")
  encoded_prompt = encoded_prompt.to(args.device)

  output_sequences = model.generate(
      input_ids=encoded_prompt,
      max_length=args.length + len(encoded_prompt[0]),
      temperature=args.temperature,
      top_k=args.k,
      top_p=args.p,
      repetition_penalty=args.repetition_penalty,
      do_sample=True,
      num_return_sequences=args.num_return_sequences,
  )

  # Remove the batch dimension when returning multiple sequences
  if len(output_sequences.shape) > 2:
    output_sequences.squeeze_()

  generated_sequences = []

  for generated_sequence_idx, generated_sequence in enumerate(output_sequences):
    generated_sequence = generated_sequence.tolist()

    # Decode text
    text = tokenizer.decode(generated_sequence, clean_up_tokenization_spaces=True)

    # Remove all text after the stop token
    text = text[: text.find(args.stop_token) if args.stop_token else None]

    # Remove the excess text that was used for pre-processing
    text = text[len(tokenizer.decode(encoded_prompt[0], clean_up_tokenization_spaces=True)) :]

    # Add the prompt at the beginning of the sequence.
    total_sequence = prompt_text + text

    generated_sequences.append(total_sequence)

  return generated_sequences

# %%
# Set this to the checkpoint you want to use for generation, or to "gpt2-medium"
# to generate with the pre-trained model without finetuning.
CHECKPOINT_PATH = '/content/drive/My Drive/finetuned_models/presidential_speeches/'

# You should try out other prompts as well as no prompt at all.
PROMPT = "Lenovo's Chromebook Duet is an interesting little device. Announced at CES, it's a Chrome OS tablet with an attachable keyboard and an attachable kickstand. What makes this device particularly interesting is just how much value is included. For $279, the kickstand and the keyboard are included in the box."


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
print("Running on device: ", device)

args = collections.defaultdict(
  model_name_or_path=CHECKPOINT_PATH,
  output_dir=CHECKPOINT_PATH,
  n_gpu=n_gpu,
  mlm=False,
  device=device,
  model_type='gpt2',
  seed=42,
  stop_token=None, # Set this if your dataset has a special word that indicates the end of a text.
  temperature=1.0,  # temperature sampling. Set this to temperature=1.0 to not use temperature.
  k=50,  # k for top-k sampling. Set this to k=0 to not use top-k.
  p=1.0,  # p for nucleus sampling. Set this to p=1.0 to not use nucleus sampling.
  repetition_penalty=None,
  length=350,  # Number of tokens to generate.
  num_return_sequences=3,  # Number of independently computed samples to generate.
)
args = DictToObj(args)

model = load_model(args)
sequences = generate_samples(args, model, PROMPT)
for idx, sequence in enumerate(sequences):
  print('\n====== GENERATION {} ======'.format(idx))
  print(sequence)
# Out:
# 06/27/2020 15:24:46 - INFO - transformers.configuration_utils -   loading configuration file /content/drive/My Drive/finetuned_models/presidential_speeches/config.json
# 06/27/2020 15:24:46 - INFO - transformers.configuration_utils -   Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 1024,
#   "n_head": 16,
#   "n_layer": 24,
#   "n_positions": 1024,
#   "n_special": 0,
#   "predict_special_tokens": true,
#   "resid_pdrop": 0.1,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "vocab_size": 50257
# }
#
# /usr/local/lib/python3.6/dist-packages/transformers/modeling_auto.py:791: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   FutureWarning,
# 06/27/2020 15:24:46 - INFO - transformers.modeling_utils -   loading weights file /content/drive/My Drive/finetuned_models/presidential_speeches/pytorch_model.bin
# Running on device:  cuda
# 06/27/2020 15:25:38 - INFO - transformers.modeling_utils -   All model checkpoint weights were used when initializing GPT2LMHeadModel.
#
# 06/27/2020 15:25:38 - INFO - transformers.modeling_utils -   All the weights of GPT2LMHeadModel were initialized from the model checkpoint at /content/drive/My Drive/finetuned_models/presidential_speeches/.
# If your task is similar to the task the model of the ckeckpoint was trained on, you can already use GPT2LMHeadModel for predictions without further training.
# 06/27/2020 15:25:38 - INFO - transformers.configuration_utils -   loading configuration file /content/drive/My Drive/finetuned_models/presidential_speeches/config.json
# 06/27/2020 15:25:38 - INFO - transformers.configuration_utils -   Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 1024,
#   "n_head": 16,
#   "n_layer": 24,
#   "n_positions": 1024,
#   "n_special": 0,
#   "predict_special_tokens": true,
#   "resid_pdrop": 0.1,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "vocab_size": 50257
# }
#
# 06/27/2020 15:25:38 - INFO - transformers.tokenization_utils_base -   Model name '/content/drive/My Drive/finetuned_models/presidential_speeches/' not found in model shortcut name list (gpt2, gpt2-medium, gpt2-large, gpt2-xl, distilgpt2). Assuming '/content/drive/My Drive/finetuned_models/presidential_speeches/' is a path, a model identifier, or url to a directory containing tokenizer files.
# 06/27/2020 15:25:38 - INFO - transformers.tokenization_utils_base -   Didn't find file /content/drive/My Drive/finetuned_models/presidential_speeches/added_tokens.json. We won't load it.
# 06/27/2020 15:25:38 - INFO - transformers.tokenization_utils_base -   Didn't find file /content/drive/My Drive/finetuned_models/presidential_speeches/tokenizer.json. We won't load it.
# 06/27/2020 15:25:38 - INFO - transformers.tokenization_utils_base -   loading file /content/drive/My Drive/finetuned_models/presidential_speeches/vocab.json
# 06/27/2020 15:25:38 - INFO - transformers.tokenization_utils_base -   loading file /content/drive/My Drive/finetuned_models/presidential_speeches/merges.txt
# 06/27/2020 15:25:38 - INFO - transformers.tokenization_utils_base -   loading file None
# 06/27/2020 15:25:38 - INFO - transformers.tokenization_utils_base -   loading file /content/drive/My Drive/finetuned_models/presidential_speeches/special_tokens_map.json
# 06/27/2020 15:25:38 - INFO - transformers.tokenization_utils_base -   loading file /content/drive/My Drive/finetuned_models/presidential_speeches/tokenizer_config.json
# 06/27/2020 15:25:38 - INFO - transformers.tokenization_utils_base -   loading file None
# 06/27/2020 15:25:39 - WARNING - transformers.modeling_utils -   Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# ====== GENERATION 0 ======
# Lenovo's Chromebook Duet is an interesting little device. Announced at CES, it's a Chrome OS tablet with an attachable keyboard and an attachable kickstand. What makes this device particularly interesting is just how much value is included. For $279, the kickstand and the keyboard are included in the box. For example, if you're an expensive customer, you can get a $299 Dell XPS 14 with the kickstand. That's $39.99 for 2 days of use.  This is a new thing for Intel. In the PC world we've seen a couple of deals with Intel. For example, at Computex last year they announced the Intel Pentium G4430, which was a version of the T4 chip inside the DDR3-2070 memory. It was a pretty cool little product with a quad core CPU, which I suppose you could say was an Intel product. It wasn't quite as powerful as the G4, but it was priced much lower as well. However, Intel took the technology, and combined it with an Xeons 8X accelerator chip, all while giving you a decent 8-inch display. They made a deal with AMD on that, even selling the board under the AMD  urlLink Unlocked OS tag 'on-par with Intel's own Xeons 8X'.  The deal still stands. The Xeons 8X chip does give the Duet a couple of very nice features. For instance, although an Xeons 8X is a quad core processor as are the other chips, it has 4MB of RAM to store the program, graphics, and possibly a modem memory. In addition, the Duet does not require dedicated memory, either a DDR3 slot or a DDR2-1600 slot. That could be helpful in some cases, but it's not as great as what you get when you use an old ATi-based PC instead of a new Intel processor. So I guess they were trying to get the price point down. The only way that
#
# ====== GENERATION 1 ======
# Lenovo's Chromebook Duet is an interesting little device. Announced at CES, it's a Chrome OS tablet with an attachable keyboard and an attachable kickstand. What makes this device particularly interesting is just how much value is included. For $279, the kickstand and the keyboard are included in the box.     urlLink The Kickstand: A Case for a Tandy.    It took 3 months to get my own new laptop, but it's now complete and running fine with a 1.8 Ghz Intel i5, 16GB RAM, and 880GB SSD. This time I'd like to give them the benefit of the doubt and let it grow on me after a while. The unit I've got is in the process of replacing an iBook (which I'm considering replacing as well, as I'm unhappy with my current model), so it can be an upgrade-friendly addition to my stack. I was initially going to go for a Mac (as the iBook is more space efficient), but I haven't found anything cheap enough for this device to fit in here. I'll report back with a comment.    urlLink The Kickstand: An Example of Google's Big Idea   I need to say something before I start taking all these little details as gospel.  When you're browsing the web (or even just looking at one from the comfort of your own house) you really can't go wrong.  There are two reasons you think about what you're saying.  First, what you're reading is really good. You'll notice it a lot.  Second, it's really convenient and intuitive. You're not stuck thinking, 'What should I say here now?' (or something like that).    urlLink Google's Big Idea and Its Problem with Users     urlLink The Problem with Users   urlLink   The Problem with Users    urlLink   The Problem with Users    urlLink   The Problem with
#
# ====== GENERATION 2 ======
# Lenovo's Chromebook Duet is an interesting little device. Announced at CES, it's a Chrome OS tablet with an attachable keyboard and an attachable kickstand. What makes this device particularly interesting is just how much value is included. For $279, the kickstand and the keyboard are included in the box. It's just a $99 buy. The price of the keyboard comes in a different range, though -- it's currently $79! A nice price, considering it's a dual-core Intel Celeron G4 with 4GB RAM. Also, you get a 4,500 mAh battery, 256GB M.2 SSD and a wireless Bluetooth keyboard. There are no other accessories listed for this device though no Windows Hello, a fingerprint reader (I don't need one) and a dock connector. While this isn't too surprising as a ThinkPad-powered device, it's also something we haven't seen in previous ThinkPads. A wireless USB keyboard is coming at an even higher price tag, $159 (with no dock connector is available at least). So the new version is for entry-level consumers and some high-end PCers (like me), not for everyone else.  With the added value, and a keyboard that's only $79, the Duet can be a great buy. In fact, it's probably worth it just for the kickstand. And, the keyboard and the kickstand can also be bought separately. The price of the new version, in turn, of course, brings the total to $299. With that, the new machine is not only worth upgrading, it costs just about as much as a second PC with a Thinkpad 4. It's $150 more, but this unit has more memory and a far more powerful Intel i5.  For one, the new ThinkPad has more than enough power for more applications. That's the real kicker. What is missing is a decent mouse and keyboard.  As a user of a Windows XP machine, I could just as easily
